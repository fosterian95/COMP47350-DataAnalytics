# %% [markdown]
# # Assignment 2: Initial Data Prep

# %% [markdown]
# In this initial phase of the assignment work, the csv file originally used for the first assignment was cleaned again using the same techniques as had been originally used in that same first assignment. There were some noted differences in this approach following the first assignment feedback.
#
# - The address column was kept in for this data preparation. While it is unlikely to provide much additional benefit to the model itself given its high cardinality, it could help in filling in other data for other columns and so was kept in
# - The price feature was not binned as it had been last time but instead was kept in its original state. Initial analysis suggests that clamping this feature might be a more appropriate means to deal with outliers. However it was decided based on the recommendation from Kelleher, Mac Namee and D'Arcy (2020) to test the effectiveness of trained models on test sets that have both been clamped and that haven't been in order to see the effect of clamping the outliers on the model performances. As such, these values will be clamped following creating the test and train sets in another notebook
# - 2022 Sale values were not removed from the dataset. While they were underrepresented in this first instance, dummy values could potentially be created to allow for a more even sampling of data and trends in the data
#
# Other than the changes listed here, other data cleaning and preparatory operations were kept the same. The original notebook will be attached with this one, containing a more in-depth analysis and justification for certain steps taken. This notebook is designed to be a much more brief cleaning and preparation of the data

# %% [markdown]
# ## Initial Assessment of Data

# %%
# Import necessary modules from both own work and as seen in sample notebook (see reference to this in markdown above)

import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import matplotlib.patches as mpatches
from geopy.geocoders import Nominatim
from matplotlib.backends.backend_pdf import PdfPages

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Read in initial csv

rppr_df = pd.read_csv('ppr-14332591.csv', keep_default_na = True, delimiter=',', skipinitialspace = True)

# %%
rppr_df.dtypes
# Out:
# Date of Sale (dd/mm/yyyy)    object
# Address                      object
# Postal Code                  object
# County                       object
# Price (€)                    object
# Not Full Market Price        object
# VAT Exclusive                object
# Description of Property      object
# Property Size Description    object
# dtype: object

# %%
# Note that price is excluded from this first alteration as more work was done to clean that feature
# Each datatype was assigned individually

rppr_df['Date of Sale (dd/mm/yyyy)'] = rppr_df['Date of Sale (dd/mm/yyyy)'].astype('datetime64[ns]')
rppr_df['Address'] = rppr_df['Address'].astype('category')
rppr_df['Postal Code'] = rppr_df['Postal Code'].astype('category')
rppr_df['County'] = rppr_df['County'].astype('category')
rppr_df['Not Full Market Price'] = rppr_df['Not Full Market Price'].astype('category')
rppr_df['VAT Exclusive'] = rppr_df['VAT Exclusive'].astype('category')
rppr_df['Description of Property'] = rppr_df['Description of Property'].astype('category')
rppr_df['Property Size Description'] = rppr_df['Property Size Description'].astype('category')

# %%
# Check the reassigning of datatypes

rppr_df.dtypes
# Out:
# Date of Sale (dd/mm/yyyy)    datetime64[ns]
# Address                            category
# Postal Code                        category
# County                             category
# Price (€)                            object
# Not Full Market Price              category
# VAT Exclusive                      category
# Description of Property            category
# Property Size Description          category
# dtype: object

# %%
rppr_df.columns
# Out:
# Index(['Date of Sale (dd/mm/yyyy)', 'Address', 'Postal Code', 'County',
#        'Price (€)', 'Not Full Market Price', 'VAT Exclusive',
#        'Description of Property', 'Property Size Description'],
#       dtype='object')

# %%
# Alter current column titles to make them easier to use programmatically in Python

rppr_df.columns = ['Date', 'Address', 'Postal_Code', 'County', 'Price', 'Not_Full_Market_Price',
                  'VAT_Exclusive', 'Description_of_Property', 'Property_Size_Description']

# %%
# Remove non-numerical characters from the price feature

for i in range(len(rppr_df.Price)):
    rppr_df.Price[i] = rppr_df.Price[i].replace('€','')
    rppr_df.Price[i] = rppr_df.Price[i].replace(',', '')

# %%
# Check that adjustment to price feature display worked

rppr_df.Price.head(5)
# Out:
# 0    260000.00
# 1     81000.00
# 2    155000.00
# 3     60000.00
# 4    277533.00
# Name: Price, dtype: object

# %%
# Alter price feature datatype

rppr_df['Price'] = pd.to_numeric(rppr_df['Price'])

# %%
# Check changing datatype was successful

rppr_df.dtypes
# Out:
# Date                         datetime64[ns]
# Address                            category
# Postal_Code                        category
# County                             category
# Price                               float64
# Not_Full_Market_Price              category
# VAT_Exclusive                      category
# Description_of_Property            category
# Property_Size_Description          category
# dtype: object

# %%
# Check for duplicate rows

rppr_df.duplicated().sum()
# Out:
# 0

# %%
# Check for duplicate columns

rppr_df_T = rppr_df.T
rppr_df_T.duplicated().sum()
# Out:
# 0

# %%
# Assess the categorical columns with initial descriptive stats to see their unique values i.e. cardinality

category_columns = rppr_df.select_dtypes(['category']).columns
rppr_df[category_columns].describe().T
# Out:
#                            count unique  \
# Address                    10000   9984
# Postal_Code                 1914     22
# County                     10000     26
# Not_Full_Market_Price      10000      2
# VAT_Exclusive              10000      2
# Description_of_Property    10000      2
# Property_Size_Description    975      4
#
#                                                                          top  \
# Address                                120 COLLEGE VIEW, BALLYMUN, DUBLIN 11
# Postal_Code                                                        Dublin 15
# County                                                                Dublin
# Not_Full_Market_Price                                                     No
# VAT_Exclusive                                                             No
# Description_of_Property                Second-Hand Dwelling house /Apartment
# Property_Size_Description  greater than or equal to 38 sq metres and less...
#
#                            freq
# Address                       2
# Postal_Code                 249
# County                     3190
# Not_Full_Market_Price      9501
# VAT_Exclusive              8425
# Description_of_Property    8395
# Property_Size_Description   696

# %%
# Check the cardinality of price, which should be high as a continuous feature

rppr_df['Price'].nunique()
# Out:
# 2270

# %%
# Check initial descriptive statistics to also examine range and standard deviation, for further assessment
# on cardinality and the overall shape of the data

rppr_df['Price'].describe()
# Out:
# count    1.000000e+04
# mean     2.534407e+05
# std      3.196092e+05
# min      5.179000e+03
# 25%      1.180000e+05
# 50%      2.000000e+05
# 75%      3.083700e+05
# max      1.630837e+07
# Name: Price, dtype: float64

# %%
# Check the cardinality of date which should be high as a continuous feature

rppr_df['Date'].nunique()
# Out:
# 2768

# %%
# View descriptive statistics of date to get sense of shape of the data

rppr_df['Date'].describe()
# Out:
# count                   10000
# unique                   2768
# top       2013-12-20 00:00:00
# freq                       34
# first     2010-01-02 00:00:00
# last      2022-12-01 00:00:00
# Name: Date, dtype: object

# %%
# check for the presence of null values in the dataframe

rppr_df.isnull().sum()
# Out:
# Date                            0
# Address                         0
# Postal_Code                  8086
# County                          0
# Price                           0
# Not_Full_Market_Price           0
# VAT_Exclusive                   0
# Description_of_Property         0
# Property_Size_Description    9025
# dtype: int64

# %% [markdown]
# ## Geolocating Addresses

# %%
# Creating small random sample from the data using just the first 100 rows

first100 = pd.DataFrame(rppr_df.head(100))
first100
# Out:
#          Date                                            Address Postal_Code  \
# 0  2016-01-03  80 THE WATER RILL, WATERSIDE SWORDS RD, MALAHI...         NaN
# 1  2013-03-15                         apt 40, 109 parnell street    Dublin 1
# 2  2011-01-14                            Cornabrone, Ballinamore         NaN
# 3  2016-10-27         46 TI CHORMAIC, GLEANN NA RI, MURROUGH AVE         NaN
# 4  2014-08-22      29 Barrettstown Meadows, Roseberry, NEWBRIDGE         NaN
# ..        ...                                                ...         ...
# 95 2017-10-02                 THOMAS ST, CASTLEBLAYNEY, MONAGHAN         NaN
# 96 2010-02-26                      5 Glendoher Park, Rathfarnham         NaN
# 97 2015-02-12                       TURLOUGH, CASTLEBAR, CO MAYO         NaN
# 98 2016-10-13               19 NEWTOWN VILLAS, BLACKROCK, DUBLIN         NaN
# 99 2015-08-19                TOMACURRY, BALLYCARNEY, ENNISCORTHY         NaN
#
#       County     Price Not_Full_Market_Price VAT_Exclusive  \
# 0     Dublin  260000.0                    No            No
# 1     Dublin   81000.0                    No            No
# 2    Leitrim  155000.0                    No            No
# 3     Galway   60000.0                    No            No
# 4    Kildare  277533.0                    No           Yes
# ..       ...       ...                   ...           ...
# 95  Monaghan   75000.0                    No            No
# 96    Dublin  410000.0                    No            No
# 97      Mayo   68000.0                    No            No
# 98    Dublin  373207.0                    No            No
# 99   Wexford   91000.0                    No            No
#
#                   Description_of_Property   Property_Size_Description
# 0   Second-Hand Dwelling house /Apartment                         NaN
# 1   Second-Hand Dwelling house /Apartment                         NaN
# 2   Second-Hand Dwelling house /Apartment                         NaN
# 3   Second-Hand Dwelling house /Apartment                         NaN
# 4           New Dwelling house /Apartment  greater than 125 sq metres
# ..                                    ...                         ...
# 95  Second-Hand Dwelling house /Apartment                         NaN
# 96  Second-Hand Dwelling house /Apartment                         NaN
# 97  Second-Hand Dwelling house /Apartment                         NaN
# 98  Second-Hand Dwelling house /Apartment                         NaN
# 99  Second-Hand Dwelling house /Apartment                         NaN
#
# [100 rows x 9 columns]

# %%
# Create a list of updated address values, all modified to lower case and removing some values that 
# that may cause errors in the address look-up or potential inconsistencies within the data returned
# Addresses were also converted to lowercase to make future analysis and comparison easier

first100_addresses_list = []
first100_addresses = first100['Address']
for address in first100_addresses:
    lowercase_address = address.lower()
    split_up_address = lowercase_address.rsplit(",", 1)
    if len(split_up_address) > 1:
        split_up_address.remove(split_up_address[0])
    print(split_up_address)
    first100_addresses_list.append(split_up_address)
# Out:
# [' malahide dublin']
# [' 109 parnell street']
# [' ballinamore']
# [' murrough ave']
# [' newbridge']
# [' hansfield']
# [' moyvane']
# [' cork']
# [' ballyhaunis']
# [' caherdavin']
# [' galway']
# [' roscommon']
# [' county roscommon']
# [' leopardstown']
# [' smithfield dublin 7']
# [' raheny dublin 5']
# [' midleton']
# [' galway']
# [' dublin']
# [' ardara']
# [' clarinbridge']
# [' malahide road']
# [' galway']
# [' sligo']
# [' straffan']
# [' killarney']
# [' dublin']
# [' lehenaghmore']
# [' donegal']
# [' finglas dublin 11']
# [' enfield']
# [' bandon']
# [' birr']
# [' piltown']
# [' dublin 13']
# [' greystones']
# [' dundrum']
# [' co. clare']
# [' dublin 24']
# [' dublin 15']
# [' co. donegal']
# [' dublin 3']
# [' bantry']
# [' waterford']
# [' lifford']
# [' leopardstown']
# [' drogheda']
# [' meath']
# [' dunlaoire']
# [' sandyford']
# [' dublin 11']
# [' rathfarnham']
# [' south dock rd dublin 4']
# [' tramore']
# [' dublin 6']
# [' waterford']
# [' mallow']
# [' johnswell rd']
# [' wicklow']
# [' knockboy']
# [' skerries']
# [' dublin 5']
# [' tipperary']
# [' louth']
# [' limerick']
# [' dublin']
# [' dun laoghaire']
# [' corbally']
# [' wexford']
# [' laois']
# [' kildare']
# [' cork']
# [' carrick on shannon']
# [' virginia']
# [' sandyford']
# [' west cork']
# [' cork']
# [' city west dublin']
# [' limerick co. limerick']
# [' clontarf']
# [' dublin 12']
# [' killarney']
# [' meath']
# [' westport']
# [' dungarvan']
# [' smithfield market dublin 7']
# [' killarney']
# [' cork']
# [' navan']
# [' dublin 16']
# [' mungret']
# [' co mayo']
# [' dublin 15']
# [' killorglin']
# [' sandyford dublin 18']
# [' monaghan']
# [' rathfarnham']
# [' co mayo']
# [' dublin']
# [' enniscorthy']

# %%
# Print out geocoded addresses to check that geocoding is working before commiting to running on all values

geolocator = Nominatim(user_agent = 'property_analysis')

for i in range(len(first100_addresses_list)):
    # print(address[0] + "," + address[1])
    address_string = first100_addresses_list[i][0]
    # print(address_string)
    try:
        location = geolocator.geocode(address_string + ", Ireland")
        print(location.address)
    except Exception:
        print(f"Geolocator couldn't get the address for address at position {i}")
    time.sleep(1)
# Out:
# Malahide, Fingal, County Dublin, Leinster, K36 HN84, Éire / Ireland
# Parnell Street, Rotunda B ED, Dublin, Dublin 1, Leinster, D01 R243, Éire / Ireland
# Ballinamore, Ballinamore Municipal District, County Leitrim, Connacht, Éire / Ireland
# Murrough Avenue, Murrough, Cathair na Gaillimhe, County Galway, Connacht, Éire / Ireland
# Newbridge, The Municipal District of Kildare — Newbridge, County Kildare, Leinster, W12 AD93, Éire / Ireland
# Hansfield, Blanchardstown-Blakestown ED, Fingal, County Dublin, Leinster, Éire / Ireland
# Moyvane, Listowel Municipal District, County Kerry, Munster, Éire / Ireland
# Cork, County Cork, Munster, T12 T997, Éire / Ireland
# Ballyhaunis, Claremorris-Swinford Municipal District, County Mayo, Connacht, F35 NF82, Éire / Ireland
# Caherdavin, The Metropolitan District of Limerick City, Limerick, County Limerick, Munster, V94TN5P, Éire / Ireland
# Cathair na Gaillimhe, County Galway, Connacht, Éire / Ireland
# County Roscommon, Connacht, Éire / Ireland
# County Roscommon, Connacht, Éire / Ireland
# Leopardstown, Galloping Green South, Stillorgan-Leopardstown ED, Dún Laoghaire-Rathdown, County Dublin, Leinster, D18 P521, Éire / Ireland
# Smithfield, Arran Quay C ED, Dublin, Dublin 7, Leinster, Éire / Ireland
# Addresses were also converted to lowercase to make future analysis and comparison easier

addresses_list = []
addresses = rppr_df['Address']
for address in addresses:
    lowercase_address = address.lower()
    split_up_address = lowercase_address.rsplit(",", 1)
    if len(split_up_address) > 1:
        split_up_address.remove(split_up_address[0])
    print(split_up_address)
    addresses_list.append(split_up_address)
# Out:
# [' malahide dublin']
# [' 109 parnell street']
# [' ballinamore']
# [' murrough ave']
# [' newbridge']
# [' hansfield']
# [' moyvane']
# [' cork']
# [' ballyhaunis']
# [' caherdavin']
# [' galway']
# [' roscommon']
# [' county roscommon']
# [' leopardstown']
# [' smithfield dublin 7']
# [' raheny dublin 5']
# [' midleton']
# [' galway']
# [' dublin']
# [' ardara']
# [' clarinbridge']
# [' malahide road']
# [' galway']
# [' sligo']
# [' straffan']
# [' killarney']
# [' dublin']
# [' lehenaghmore']
# [' donegal']
# [' finglas dublin 11']
# [' enfield']
# [' bandon']
# [' birr']
# [' piltown']
# [' dublin 13']
# [' greystones']
# [' dundrum']
# [' co. clare']
# [' dublin 24']
# [' dublin 15']
# [' co. donegal']
# [' dublin 3']
# [' bantry']
# [' waterford']
# [' lifford']
# [' leopardstown']
# [' drogheda']
# [' meath']
# [' dunlaoire']
# [' sandyford']
# [' dublin 11']
# [' rathfarnham']
# [' south dock rd dublin 4']
# [' tramore']
# [' dublin 6']
# [' waterford']
# [' mallow']
# [' johnswell rd']
# [' wicklow']
# [' knockboy']
# [' skerries']
# [' dublin 5']
# [' tipperary']
# [' louth']
# [' limerick']
# [' dublin']
# [' dun laoghaire']
# [' corbally']
# [' wexford']
# [' laois']
# [' kildare']
# [' cork']
# [' carrick on shannon']
# [' virginia']
# [' sandyford']
# [' west cork']
# [' cork']
# [' city west dublin']
# [' limerick co. limerick']
# [' clontarf']
# [' dublin 12']
# [' killarney']
# [' meath']
# [' westport']
# [' dungarvan']
# [' smithfield market dublin 7']
# [' killarney']
# [' cork']
# [' navan']
# [' dublin 16']
# [' mungret']
# [' co mayo']
# [' dublin 15']
# [' killorglin']
# [' sandyford dublin 18']
# [' monaghan']
# [' rathfarnham']
# [' co mayo']
# [' dublin']
# [' enniscorthy']
# [' dublin']
# [' dublin 6']
# [' dublin 12']
# [' kinsale']
# [' wicklow']
# [' dublin']
# [' rathfarnham']
# [' tyrrelstown']
# [' blarney']
# [' ennis']
# [' louth']
# [' cork']
# [' bantry']
# [' dublin 9']
# [' dundalk']
# [' galway']
# [' athlone']
# [' dublin']
# [' blackrock']
# [' dublin']
# [' blarney']
# [' thurles']
# [' waterford']
# [' cork']
# [' county clare']
# [' wexford']
# [' dublin 15']
# [' bettystown']
# [' main st  mallow']
# [' bandon']
# [' galway']
# [' killarney']
# [' termonfeckin']
# [' annacotty']
# [' athlone']
# [' leitrim']
# [' dooradoyle']
# [' sligo']
# [' rahanine']
# [' beaumount woods']
# [' oran']
# [' monaghan']
# [' carrigtwohill']
# [' glenmore']
# [' rathfarnham']
# [' dublin 3']
# [' kildare']
# [' co wexford']
# [' cork']
# [' williamstown rd']
# [' dromiskin']
# [' monaghan']
# [' lucan']
# [' clonsilla dublin 15']
# [' swords']
# [' louth']
# [' dublin 16']
# [' westmeath']
# [' westmeath']
# [' lucan']
# [' limerick']
# [' dublin 11']
# [' tramore']
# [' dublin 9']
# [' co carlow']
# [' limerick']
# [' co roscommon']
# [' leitrim']
# [' limerick']
# [' kildare']
# [' delgany']
# [' the swan']
# [' thurles']
# [' wicklow']
# [' newcastle']
# [' wicklow']
# [' dublin 9']
# [' rosslare strand']
# [' galway']
# [' louth']
# [' donegal']
# [' lower kimmage rd dublin 6w']
# [' galway city']
# [' co laois']
# [' cork']
# [' dublin']
# [' dublin']
# [' kildare']
# [' the gallops leopardstown dublin 18']
# [' dundrum dublin 16']
# [' kilkenny']
# [' portlaoise']
# [' ennis']
# [' tallaght dublin 24']
# [' carrick on shannon']
# [' waterford']
# [' kilkenny']
# [' swords']
# [' dublin 22']
# [' longford']
# [' louth']
# [' raglan road']
# [' navan']
# [' cashel']
# [' county dublin']
# [' mallow']
# [' limerick']
# [' miltown malbay']
# [' balbriggan']
# [' kerry']
# [' co wexford']
# [' limerick']
# [' whiterock hill']
# [' dromahair']
# [' newbridge']
# [' co. laois']
# [' windtown']
# [' dublin 1']
# [' kilcoole']
# [' co limerick']
# [' carrigaline']
# [' swords']
# [' birr']
# [' dublin 8']
# [' dublin']
# [' drogheda']
# [' dublin 6']
# [' bray']
# [' greystones']
# [' dublin 8']
# [' kerry']
# [' ladyswell  cashel']
# [' mayo']
# [' dring']
# [' rialto']
# [' daingean']
# [' cork']
# [' limerick']
# [' ballyconnell']
# [' cork']
# [' glenageary']
# [' fairview dublin 3']
# [' dublin 15']
# [' newtowncashel']
# [' co donegal']
# [' beaumont dublin 9']
# [' clifden']
# [' dublin 24']
# [' portlaoise']
# [' clifden']
# [' meath']
# [' laois']
# [' louth']
# [' sligo']
# [' wexford']
# [' fenagh']
# [' new ross']
# [' corofin']
# [' birr']
# [' templeogue']
# [' sligo']
# [' roscommon']
# [' dublin 8']
# [' co dublin']
# [' dunfanaghy']
# [' kilcock']
# [' watergrasshill']
# [' kildare']
# [' trim']
# [' cork']
# [' ballinrobe']
# [' old leighlin']
# [' lucan']
# [' lucan']
# [' kilkenny']
# [' dublin 8']
# [' dublin']
# [' co. wicklow']
# [' dublin 4']
# [' naas']
# [' wicklow']
# [' dublin 7']
# [' offaly']
# [' swords rd malahide']
# [' halfway house']
# [' belmullet']
# [' cork']
# [' portarlington']
# [' waterford']
# [' co kerry']
# [' wexford']
# [' dublin 9']
# [' dublin']
# [' foxwood']
# [' ballinhassig']
# [' meath']
# [' bantry']
# [' blackrock']
# [' ballyjamesduff']
# [' sutton dublin 13']
# [' moate']
# [' trim']
# [' ballygawley']
# [' courtmacsherry']
# [' dublin']
# [' dublin 5']
# [' glanmire']
# [' co galway']
# [' letterkenny']
# [' cloughjordan']
# [' ballisodare']
# [' ashtown dublin 15']
# [' kildare']
# [' ashtown']
# [' dublin 18']
# [' co cork']
# [' nenagh']
# [' clare']
# [' sligo']
# [' athlone']
# [' knocknacarra']
# [' dublin 8']
# [' dublin 6']
# [' waterford']
# [' dublin 11']
# [' co waterford']
# [' trim']
# [' co. laois']
# [' lucan']
# [' gort']
# [' kilmallock']
# [' duncormick']
# [' kildare']
# [' monaghan']
# [' woodstown']
# [' kinsale']
# [' dublin 4']
# [' galway']
# [' cork']
# [' dublin 15']
# [' dublin 12']
# [' drogheda']
# [' cork city']
# [' sutton']
# [' gorey']
# [' mullingar']
# [' sandymount']
# [' co cork']
# [' dublin 18']
# [' raheen']
# [' waterford']
# [' termonfeckin']
# [' kilternan']
# [' donabate']
# [' fairview']
# [' kilbaha']
# [' cork']
# [' dublin']
# [' swords']
# [' galway']
# [' lucan']
# [' co. louth']
# [' co. dublin']
# [' monasterevin']
# [' off blarney st']
# [' limerick']
# [' kiltipper']
# [' co galway']
# [' co. sligo']
# [' dublin 14']
# [' louth']
# [' skerries']
# [' limerick']
# [' dublin']
# [' castleknock']
# [' meath']
# [' passage west']
# [' mullingar']
# [' glenamuck road']
# [' douglas']
# [' dun laoghaire']
# [' wicklow']
# [' cork']
# [' ballyfermot']
# [' dublin']
# [' dublin 4']
# [' dublin 15']
# [' streamstown']
# [' athy']
# [' caherdaniel']
# [' galway']
# [' co donegal']
# [' kerry']
# [' millstreet']
# [' park west dublin 12']
# [' dublin 7']
# [' newcastle']
# [' malahide']
# [' dublin 15']
# [' connamara']
# [' sandyford']
# [' greystones']
# [' wicklow town']
# [' limerick']
# [' tullamore']
# [' longford']
# [' carlow']
# [' tramore']
# [' county laois']
# [' bray']
# [' co cavan']
# [' killiney']
# [' donegal']
# [' donard']
# [' tralee']
# [' mullingar']
# [' killashee']
# [' cork']
# [' dunboyne road  maynooth']
# [' co waterford']
# [' bettystown']
# [' portarlington']
# [' dungarvan']
# [' crumlin']
# [' tralee']
# [' limerick']
# [' ballinamore']
# [' straffan']
# [' clonsilla dublin 15']
# [' dun laoghaire']
# [' tuam']
# [' tyrellstown']
# [' mucklagh']
# [' dublin 14']
# [' santry dublin 9']
# [' celbridge']
# [' dublin 8']
# [' drogheda']
# [' dublin 18']
# [' aclare']
# [' county kerry']
# [' gorey']
# [' skerries']
# [' dunmanway']
# [' louth']
# [' fairview']
# [' tallaght dublin 24']
# [' co. wexford']
# [' terenure']
# [' rathfarnham dublin 14']
# [' dublin 3']
# [' dublin']
# [' tralee']
# [' cork']
# [' derrybeg']
# [' letterkenny']
# [' dundalk']
# [' ballsbridge']
# [' wicklow harbour']
# [' malahide']
# [' castaheaney']
# [' dublin']
# [' blackpool']
# [' longford']
# [' wicklow']
# [' co cork']
# [' enniscorthy']
# [' blackrock']
# [' malahide']
# [' co. sligo']
# [' castlegregory']
# [' carrigaline']
# [' sligo']
# [' knock']
# [' co westmeath']
# [' dublin 5']
# [' ballinlough']
# [' dublin']
# [' cork']
# [' tallaght dublin 24']
# [' kilmoney rd']
# [' kilmartin']
# [' co mayo']
# [' leighlinbridge']
# [' cavan']
# [' westmeath']
# [' tipperary']
# [' artane dublin 5']
# [' county leitrim']
# [' co wicklow']
# [' grand canal dock']
# [' galway']
# [' dundalk']
# [' dublin 6']
# [' clonee']
# [' spa glen']
# [' co leitrim']
# [' drogheda']
# [' celbridge']
# [' lusk']
# [' billis']
# [' dun laoghaire']
# [' cloyne']
# [' co sligo']
# [' merlin park']
# [' new ross']
# [' co dublin']
# [' carrigaline']
# [' celbridge']
# [' louth']
# [' longford']
# [' navan']
# [' clonee dublin 15']
# [' blackcastle']
# [' kerry']
# [' off james street']
# [' clondalkin dublin 22']
# [' co donegal']
# [' swinford']
# [' carrick on shannon']
# [' clondalkin']
# [' ballisodare town centre']
# [' dublin 14']
# [' dublin 1']
# [' enniscorthy']
# [' cork']
# [' dooradoyle']
# [' co. kilkenny']
# [' fermoy']
# [' co wicklow']
# [' ballsbridge']
# [' balgriffin']
# [' galway']
# [' dublin 15']
# [' gurranabraher']
# [' tramore']
# [' dundalk']
# [' howth']
# [' cork']
# [' co cork']
# [' dublin 4']
# [' sandyford']
# [' leighlinbridge']
# [' kildare']
# [' market st']
# [' carlow']
# [' killarney']
# [' dublin 1']
# [' slane']
# [' cork']
# [' the paddocks']
# [' drumully']
# [' kinsale']
# [' lucan']
# [' kells']
# [' thurles']
# [' dublin 6w']
# [' bettystown']
# [' skerries']
# [' ballybofey']
# [' castletroy']
# [' ballycanew']
# [' co sligo']
# [' dublin 16']
# [' dublin 16']
# [' tralee']
# [' louisburgh']
# [' drummin village']
# [' carrick on shannon']
# [' dublin 3']
# [" st margaret's road"]
# [' lee rd']
# [' sandyford']
# [' dublin 11']
# [' cavan']
# [' cork']
# [' dublin 8']
# [' co. wexford']
# [' co waterford']
# [' co donegal']
# [' celbridge']
# [' cork']
# [' county limerick']
# [' tramore']
# [' cork']
# [' dublin 5']
# [' co offaly']
# [' tipperary']
# [' ballybane']
# [' limerick']
# [' wexford']
# [' thomas davis street west']
# [' limerick']
# [' waterford']
# [' meath']
# [' mullingar']
# [' galway']
# [' gowran']
# [' galway']
# [' dublin']
# [' clogherhead']
# [' dublin 22']
# [' half way']
# [' dublin 15']
# [' goatstown road']
# [' terenure']
# [' dublin 14']
# [' kenmare']
# [' sandyford dublin 18']
# [' dublin']
# [' newtownmountkennedy']
# [' county kerry']
# [' royal canal park dublin 15']
# [' dublin']
# [' cavan']
# [' westport']
# [' st lukes']
# [' the gallops']
# [' salthill']
# [' ballina']
# [' castlemaine']
# [' co. wicklow']
# [' skerries']
# [' dublin 22']
# [' blackrock']
# [' kilkenny']
# [' dublin 13']
# [' county meath']
# [' dublin 24']
# [' wexford']
# [' dunkineely']
# [' lucan']
# [' dublin 8']
# [' gorey wexford']
# [' dublin 9']
# [' tramore']
# [' mountrath']
# [' dublin']
# [' galway']
# [' tallaght dublin 24']
# [' dublin 6w']
# [' crowe st']
# [' ballymote']
# [' dunboyne']
# [' dyer st']
# [' dublin 18']
# [' dublin 15']
# [' mallow']
# [' yeats way dublin 22']
# [' clonakilty']
# [' co. wicklow']
# [' county limerick']
# [' leixlip']
# [' clifden']
# [' kilkenny']
# [' navan']
# [' dublin 16']
# [' athy']
# [' dublin 18']
# [' clonakilty']
# [' wicklow']
# [' dundalk']
# [' kilcormac']
# [" st. margaret's road"]
# [' clonmel']
# [' dublin 7']
# [' rialto']
# [' roscommon']
# [' duncannon']
# [' dublin 3']
# [' bray']
# [' wicklow']
# [' co donegal']
# [' killeshandra']
# [' new road']
# [' co leitrim']
# [' galway']
# [' robswall']
# [' cork']
# [' dublin 15']
# [' donegal']
# [' kiltegan']
# [' cualanor']
# [' hazeldene']
# [' westmeath']
# [' dublin 5']
# [' achill']
# [' nenagh']
# [' donegal']
# [' naas']
# [' kilkenny']
# [' donegal']
# [' fairview']
# [' blarney']
# [' newbridge']
# [' dublin 8']
# [' clonakilty']
# [' dublin']
# [' navan']
# [' blackrock']
# [' drumcondar']
# [' innishannon']
# [' galway']
# [' rush']
# [' fairview']
# [' rathcoole']
# [' meath']
# [' rathfarnham']
# [' county laois']
# [' dublin 7']
# [' phibsborough dublin 7']
# [' dublin 3']
# [' leamlara']
# [' swords']
# [' waterford']
# [' meath']
# [' rathangan']
# [' co cork']
# [' kildare']
# [' wexford']
# [' dundalk']
# [' galway']
# [' tullaghan']
# [' louth']
# [' main st ballycotton']
# [' cobh']
# [' rathcoole']
# [' kilfinane']
# [' leixlip']
# [' waterford']
# [' castlerea']
# [' arklow']
# [' bettystown']
# [' tipperary']
# [' rosslare']
# [' ballybofey']
# [' dublin']
# [' wicklow']
# [' clonsilla']
# [' portlaoise']
# [' co meath']
# [' dublin 7']
# [' swords']
# [' kilmore']
# [' castleknock']
# [' co kilkenny']
# [' beresford st dublin 7']
# [' mullagh']
# [' cork']
# [' celbridge']
# [' dublin 17']
# [' dublin']
# [' killester']
# [' knocknacarra']
# [' ashourne']
# [' foxwood']
# [' monkstown']
# [' newbridge']
# [' castleknock dublin 15']
# [' westport']
# [' listowel']
# [' galway']
# [' roscommon']
# [' co mayo']
# [' ballinlough']
# [' cork']
# [' dublin 6']
# [' sandyford']
# [' malahide']
# [' portlaoise']
# [' dualla road cashel']
# [' dunboyne']
# [' glasnevin']
# [' dublin 5']
# [' roscommon']
# [' hill street']
# [' dublin 7']
# [' rathgar']
# [' dungarvan']
# [' tallaght dublin 24']
# [' ballymote']
# [' crandonagh']
# [' holiday village']
# [' ashtown']
# [' galway']
# [' stillorgan']
# [' baltimore']
# [' foxrock dublin 18']
# [' co meath']
# [' dublin 16']
# [' balgriffin']
# [' county roscommon']
# [' clontarf']
# [' co cork']
# [' louth']
# [' longford']
# [' shankill']
# [' robertstown']
# [' dublin 24']
# [' newbridge']
# [' limerick']
# [' lucan']
# [' galway']
# [' cork']
# [' kinsale']
# [' galway']
# [' midleton']
# [' ballybunion']
# [' newpark upper']
# [' limerick']
# [' co waterford']
# [' dublin']
# [' lanesboro']
# [' arklow']
# [' strandhill']
# [' drummin village']
# [' dublin 8']
# [' sandyford']
# [' roscommon']
# [' adare']
# [' derrinturn']
# [' dublin 24']
# [' dublin 8']
# [' wexford']
# [' limerick']
# [' adare']
# [' co cavan']
# [' clare']
# [' tallaght']
# [' monaghan']
# [' finglas dublin 11']
# [' thomastown']
# [' cavan']
# [' kingscourt']
# [' clondalkin']
# [' moycullen']
# [' ballycullen']
# [' dublin 12']
# [' dublin 13']
# [' glenealy']
# [' gorey']
# [' co limerick']
# [' barna']
# [' dublin 15']
# [' kerry']
# [' abbeyfeale']
# [' maynooth']
# [' letterkenny']
# [' meath']
# [' sutton']
# [' ballyhaise']
# [' kinsale']
# [' donabate']
# [' carlow']
# [' ballybrack']
# [' ballinasloe']
# [' kinsale']
# [' dunshaughlin']
# [' flesk road  killarney']
# [' lifford']
# [' cork']
# [' laois']
# [' rathfarnham dublin 16']
# [' dublin 18']
# [' dublin']
# [' edenderry']
# [' navan']
# [' offaly']
# [' laois']
# [' clonard']
# [' galway']
# [' co donegal']
# [' johnstown']
# [' dublin']
# [' louth']
# [' kilkee']
# [' louth']
# [' tullamore']
# [' serpentine ave dublin 4']
# [' co carlow']
# [' bunclody']
# [' dublin 8']
# [' birr']
# [' dublin 14']
# [' county dublin']
# [' dunmore rd']
# [' westmeath']
# [' sligo']
# [' dublin 5']
# [' county dublin']
# [' county tippeary']
# [' limerick']
# [' bundoran']
# [' tralee']
# [' limerick']
# [' templemore']
# [' limerick']
# [' sneem rd']
# [' ballinasloe']
# [' salthill']
# [' naas']
# [' co. westmeath']
# [' louth']
# [' santry']
# [' laois']
# [' dublin 8']
# [' mayo']
# [' co mayo']
# [' meath']
# [' limerick']
# [' laghey']
# [' co cork']
# [' ennis']
# [' terenure']
# [' castleisland']
# [' galway']
# [' co sligo']
# [' co kildare']
# [' ennis']
# [' sligo']
# [' dunmore east']
# [' dublin 16']
# [' sandymount dublin 4']
# [' laois']
# [' killenard']
# [' dublin 11']
# [' rathmullan']
# [' dublin 5']
# [' dublin 24']
# [' cork']
# [' donegal']
# [' swords']
# [' dublin 3']
# [' kinsale']
# [' douglas']
# [' enniscorthy']
# [' cork']
# [' dublin6']
# [' dublin 18']
# [' killorglin']
# [' galway']
# [' clonskeagh  dublin 14']
# [' dublin 2']
# [' bray']
# [' asgard rd dublin 2']
# [' carrigtwohill']
# [' dublin 17']
# [' hollystown']
# [' harolds cross']
# [' balgriffin']
# [' drumcondra']
# [' wexford']
# [' tipperary']
# [' kinsealy']
# [' ballyfermot dublin 10']
# [' dublin 7']
# [' enfield']
# [' blackrock']
# [' galway']
# [' robswall']
# [' killarney']
# [' county cork']
# [' gort']
# [' knockenduff']
# [' clontarf']
# [' wexford']
# [' letterkenny']
# [' wicklow']
# [' glanmire']
# [' drogheda']
# [' fairhill  killarney']
# [' roscommon']
# [' raheny dublin 5']
# [' co.mayo']
# [' courtown']
# [' upper william street']
# [' balbriggan']
# [' longford']
# [' co wexford']
# [' clonmel rd']
# [' wexford']
# [' westport']
# [' letterkenny']
# [' cliffoney']
# [' swords']
# [' maryborough hill']
# [' portmarnock']
# [' dublin 22']
# [' westport']
# [' co louth']
# [' adamstown']
# [' newbridge']
# [' cork']
# [' co kildare']
# [' wexford']
# [' tulsk']
# [' ratoath']
# [' portlaoise']
# [' galway']
# [' dublin 6']
# [' lehenaghmore']
# [' county donegal']
# [' castleknock dublin 15']
# [' santry']
# [' county kildare']
# [' crosshaven']
# [' dundalk']
# [' raheny rd dublin 5']
# [' kevin street']
# [' south circular road']
# [' cork']
# [' cavan']
# [' wicklow']
# [' co meath']
# [' ballsbridge dublin 4']
# [' cork']
# [' county cork']
# [' athlone']
# [' swinford']
# [' limerick']
# [' portlaoise']
# [' monkstown']
# [' limerick city']
# [' dartry rd dublin 6']
# [' co kerry']
# [' wicklow']
# [' howth']
# [' cork']
# [' killashee']
# [' loughrea']
# [' limerick']
# [' dublin 6']
# [' cobh']
# [' letterkenny']
# [' fermoy']
# [' mungret']
# [' dundalk']
# [' dundalk louth']
# [' wexford']
# [' foxford']
# [' limerick']
# [' sligo']
# [' roscommon']
# [' ballycastle']
# [' donabate']
# [' co mayo']
# [' dublin']
# [' kilkenny']
# [' portlaoise']
# [' dublin 9']
# [' glengariff']
# [' dundalk']
# [' ladysbridge']
# [' dublin']
# [' mount merrion']
# [' kilkenny']
# [' dublin 12']
# [' dublin 24']
# [' dublin 6']
# [' drogheda']
# [' dublin']
# [' muine bheag']
# [' dublin']
# [' ashtown']
# [' limerick']
# [' drogheda']
# [' capel street']
# [' kerry']
# [' passage west']
# [' bandon']
# [' bray']
# [' greystones']
# [' dublin 6']
# [' arbour hill']
# [' dublin 14']
# [' rathgar']
# [' tullamore']
# [' dublin 5']
# [' carbury']
# [' waterford']
# [' wicklow']
# [' county dublin']
# [' cork']
# [' portmarnock']
# [' galway']
# [' co galway']
# [' two mile house']
# [' leamlara']
# [' sandyford']
# [' bailieborough']
# [' athy']
# [' galway']
# [' carlow']
# [' dublin']
# [' artane']
# [' killiney']
# [' rush']
# [' dublin']
# [' tralee']
# [' limerick']
# [' dublin 12']
# [' dublin']
# [' waterford']
# [' dundrum']
# [' tinahely']
# [' mayo']
# [' dundalk']
# [' co. wexford']
# [' dublin']
# [' maree']
# [' dublin 9']
# [' lucan']
# [' south circular road']
# [' ashford']
# [' callan']
# [' cappagh dublin 11']
# [' sligo']
# [' tipperary']
# [' mullingar']
# [' westport']
# [' donegal']
# [' donegal']
# [' galway']
# [' cavan']
# [' kildare town']
# [' crosslanes']
# [' nenagh']
# [' youghal']
# [' kilmallock']
# [' cork city']
# [' dublin 11']
# [' carrigaline']
# [' clonsilla dublin 15']
# [' cork']
# [' kilmoney road']
# [' malahide']
# [' bonniconlon']
# [' blarney']
# [' sligo']
# [' ennis']
# [' barna']
# [' mayo']
# [' new ross']
# [' co cork']
# [' trim']
# [' dublin']
# [' trim']
# [' kildinan']
# [' brownsbarn']
# [' co kilkenny']
# [' meath']
# [' waterford']
# [' donnybrook']
# [' portlaoise']
# [' galbally']
# [' bunclody']
# [' tralee']
# [' co. clare']
# [' cobh']
# [' roscommon']
# [' wexford']
# [' carlow']
# [' headford road']
# [' dublin']
# [' cork']
# [' tipperary']
# [' co sligo']
# [' dublin 8']
# [' dublin']
# [' headford road']
# [' rosslare strand']
# [' limerick']
# [' loughrea']
# [' kilkenny']
# [' dublin 3']
# [' laois']
# [' passage west']
# [' co kerry']
# [' dublin 22']
# [' graiguecullen']
# [' ballyfermot']
# [' blackrock']
# [' dublin 5']
# [' dundrum rd']
# [' dublin 11']
# [' wicklow']
# [' barracks']
# [' terenure dublin 12']
# [' co westmeath']
# [' gorey']
# [' sligo']
# [' kinsale']
# [' wexford']
# [' ballsbridge dublin 4']
# [' leixlip']
# [' co meath']
# [' greystones']
# [' inner ring rd']
# [' terenure dublin 6w']
# [' gort']
# [' ballincollig']
# [' new ross']
# [' aughnacliffe']
# [' dublin 13']
# [' woodside']
# [' milltown']
# [' station road']
# [' dublin 9']
# [' kildare']
# [' newport']
# [' dublin']
# [' co wicklow']
# [' kildare']
# [' kinsale']
# [' limerick']
# [' dublin 12']
# [' donegal']
# [' lucan']
# [' tipperary']
# [' anglesea road']
# [' cappoquin']
# [' dublin 6w']
# [' athlone']
# [' dromore west']
# [' meath']
# [' dundalk']
# [' gorey']
# [' ashbourne']
# [' gorey']
# [' churchtown']
# [' dublin 9']
# [' ovens']
# [' galway']
# [' dublin 15']
# [' kildare']
# [' burlington road']
# [' dublin']
# [' listowel']
# [' castlemartyr']
# [' mallow']
# [' ballina']
# [' dublin']
# [' drumcondra']
# [' sligo']
# [' dunboyne']
# [' ballina']
# [' newtownmountkennedy']
# [' kerry']
# [' kerry']
# [' limerick']
# [' foxrock dublin 18']
# [' dublin 3']
# [' brownsbarn']
# [' monasterevin']
# [' college road   rathfarnham']
# [' callan rd']
# [' wexford']
# [' ballinasloe']
# [' cork']
# [' clare']
# [' dublin 18']
# [' drimnagh dublin 12']
# [' dublin 8']
# [' clonakilty']
# [' clashmore']
# [' city quay']
# [' sandyford']
# [' dublin 5']
# [' mountrath']
# [' tipperary']
# [' monkstown']
# [' claremorris']
# [' dundalk']
# [' ballintubber']
# [' cooraclare']
# [' tullamore']
# [' ratoath']
# [' kilsheelan']
# [' tipperary']
# [' dublin 2']
# [' ashtown']
# [' navan']
# [' dublin 1']
# [' ennis']
# [' cork']
# [' tramore']
# [' co dublin']
# [' dublin 15']
# [' navan']
# [' county louth']
# [' leixlip']
# [' co clare']
# [' co. cork']
# [' dublin 8']
# [' clonard']
# [' galway']
# [' dublin']
# [' sean mulvoy rd']
# [' county leitrim']
# [' meath']
# [' old cratloe road']
# [' santry dublin 9']
# [' navan']
# [' castleknock']
# [' cork']
# [' sandyford']
# [' malahide']
# [' westport']
# [' ballycullen']
# [' kilsheelan']
# [' donegal']
# [' cavan']
# [' firhouse dublin 24']
# [' cork']
# [' dublin 9']
# [' westmeath']
# [' balbriggan']
# [' dublin 22']
# [' dublin 15']
# [' rivercourt']
# [' cavan']
# [' co cork']
# [' hollystown']
# [' kildare']
# [' dublin 14']
# [' clare']
# [' rathaspeck']
# [' navan']
# [' drogheda']
# [' monaghan']
# [' louth']
# [' ovens']
# [' carndonagh']
# [' dublin 6']
# [' mallow']
# [' dublin']
# [' baldoyle dublin 13']
# [' dublin 8']
# [' cork']
# [' co dublin']
# [' enniscorthy']
# [' ballaghkeen north']
# [' bettystown']
# [' dublin']
# [' dublin 10']
# [' limekiln lane']
# [' martiemo gardens west']
# [' wexford']
# [' kildare']
# [' portarlington']
# [' balbriggan']
# [' kildare']
# [' galway']
# [' blanchardstown']
# [' rathfarnham dublin 14']
# [' navan']
# [' co waterford']
# [' cloghan']
# [' marianella']
# [' o briens bridge']
# [' dublin 5']
# [' listowel']
# [' dublin']
# [' duncormick']
# [' tullow']
# [' maynooth']
# [' kerry']
# [' bailieborough']
# [' cork']
# [' thurles']
# [' glasheen road']
# [' dublin']
# [' cork']
# [' dublin']
# [' county dublin']
# [' dublin 20']
# [' drogheda']
# [' ennis']
# [' dublin']
# [' churchbay rd']
# [' cork']
# [' cavan']
# [' dean court dublin 8']
# [' co kerry']
# [' clonsilla dublin 15']
# [' donegal']
# [' dun laoghaire']
# [' dublin 18']
# [' co donegal']
# [' dublin 6']
# [' co. roscommon']
# [' co. cork']
# [' cavan']
# [' kildare']
# [' offaly']
# [' gorey']
# [' mullingar']
# [' ferrybank']
# [' dublin']
# [' craughwell']
# [' cork']
# [' ennis']
# [' co dublin']
# [' dublin']
# [' baldonnel']
# [' cork']
# [' ballina']
# [' dun laoghaire']
# [' kilrush']
# [' co. mayo']
# [' blackrock']
# [' kilkenny']
# [' st. patricks road']
# [' dublin 3']
# [' passage west']
# [' castletownroche']
# [' sligo']
# [' donegal']
# [' drogheda']
# [' dublin 6']
# [' kerry']
# [' navan']
# [' dublin 1']
# [' athlone']
# [' mullingar']
# [' letterkenny']
# [' dublin']
# [' leopardstown']
# [' dublin']
# [' dun laoghaire']
# [' macroom']
# [' barrow street']
# [' ballincollig']
# [' tullamore']
# [' hollywood']
# [' and 44/45  southern road']
# [' enfield']
# [' tipperary']
# [' cork']
# [' tipperary']
# [' ongar village']
# [' tipperary']
# [' co clare']
# [' stradbally']
# [' meath']
# [' glanmire']
# [' beaufort']
# [' wicklow']
# [' co laois']
# [' navan']
# [' castleisland']
# [' swords']
# [' enniscorthy']
# [' delgany']
# [' ballinteer road']
# [' catherine place']
# [' killorglin']
# [' ashbourne']
# [' tralee']
# [' blarney']
# [' gretystones']
# [' dublin 24']
# [' kilkenny']
# [' portarlington']
# [' ranelagh']
# [' ballina']
# [' co. westmeath']
# [' cavan']
# [' dublin 15']
# [' harbour rd']
# [' dublin 24']
# [' dublin 16']
# [' dublin 4']
# [' donnybrook dublin 4']
# [' clonmel']
# [' dublin city']
# [' cork']
# [' schull']
# [' castletroy']
# [' letterkenny']
# [' ardfinnan']
# [' balbriggan']
# [' tallaght']
# [' santry demense']
# [' saggart']
# [' cavan']
# [' miltown malbay']
# [' leitrim']
# [' limerick']
# [' dublin 2']
# [' glanmire']
# [' kilkenny']
# [' waterford']
# [' county galway']
# [' new ross']
# [' dublin 3']
# [' knocknacarra']
# [' galway']
# [' tipperary']
# [' westport']
# [' county longford']
# [' galway']
# [' artane']
# [' new ross']
# [' limerick']
# [' enniscorthy']
# [' carlingford']
# [' ardmore']
# [' cavan']
# [' cork']
# [' dublin 15']
# [' kilkenny']
# [' dublin rd']
# [' dublin']
# [' co tipperary']
# [' co kildare']
# [' co. tipperary']
# [' airport road']
# [' rosscarbery']
# [' malahide']
# [' blanchardstown']
# [' kildare']
# [' athlone']
# [' louth']
# [' hansfield']
# [' glasnevin']
# [' tipperary']
# [' dublin 8']
# [' sandyford']
# [' castleknock dublin 15']
# [' celbridge']
# [' walshestown']
# [' laois']
# [' collon']
# [' cork']
# [' dublin']
# [' ratoath rd dublin 15']
# [' castletownbere']
# [' bantry']
# [' ardmore']
# [' dublin']
# [' swords']
# [' sligo']
# [' beaumont']
# [' clontarf']
# [' dublin 16']
# [' limerick']
# [' dublin rd']
# [' dublin']
# [' malahide road balgriffin']
# [' galway']
# [' dublin 22']
# [' dublin']
# [' kerry']
# [' kildare']
# [' co. dublin']
# [' sandford dublin 6']
# [' wexford']
# [' dublin 22']
# [' dublin']
# [' louth']
# [' beauparc']
# [' stamullen']
# [' rathdrum']
# [' cork']
# [' rathdrum']
# [' co wicklow']
# [' castleconnell']
# [' kilfinnane']
# [' dublin 15']
# [' kerry']
# [' co. cork']
# [' mayo']
# [' nenagh']
# [' co cork']
# [' chapelizod dublin 20']
# [' galway']
# [' banagher']
# [' bray']
# [' douglas']
# [' county kildare']
# [' milltown']
# [' dungarvan']
# [' carrickmacross']
# [' crosshaven']
# [' dublin 18']
# [' dublin 4']
# [' dun-laoghaire']
# [' clane']
# [' ashtown']
# [' dundalk']
# [' co kerry']
# [' donabate']
# [' mulhuddart']
# [' kerry']
# [' galway']
# [' killiney']
# [' cork']
# [' galway']
# [' tallaght']
# [' nenagh']
# [' 35a  35b  40  41 shannon grove']
# [' dublin 11']
# [' waterford']
# [' dublin 16']
# [' brittas bay']
# [' blessington']
# [' kilkenny']
# [' co tipperary']
# [' robertstown']
# [' portlaoise']
# [' cork city']
# [' sligo']
# [' dublin 6']
# [' castleknock dublin 5']
# [' douglas']
# [' co limerick']
# [' dublin 8']
# [' co cork']
# [' castleconnell']
# [' dublin 16']
# [' shankill']
# [' louth']
# [' meath']
# [' limerick']
# [' blessington']
# [' achill sound']
# [' dublin 14']
# [' swords']
# [' athy']
# [' doneraile']
# [' wicklow']
# [' baldoyle']
# [' gorey']
# [' drumcondra']
# [' carrignavar']
# [' athlone']
# [' county cork']
# [' shillelagh']
# [' clongriffin']
# [' upper glenageary road']
# [' the coast']
# [' louth']
# [' dublin']
# [' tralee']
# [' dublin 8']
# [' dublin 5']
# [' drogheda']
# [' stonepark']
# [' harolds cross dublin 6w']
# [' walkinstown']
# [' listowel']
# [' offaly']
# [' ranelagh']
# [' dublin']
# [' clonliffe road']
# [' castletroy']
# [' mullingar']
# [' skerries']
# [' clondalkin dublin 22']
# [' portlaoise']
# [' dunshaughlin']
# [' limerick']
# [' co dublin']
# [' cork']
# [' drogheda']
# [' dublin 9']
# [' mountmellick']
# [' tullyallen']
# [' dublin 6']
# [' stamullen']
# [' kerry']
# [' dublin 9']
# [' dublin 17']
# [' sallins']
# [' rush']
# [' county kerry']
# [' greystones']
# [' co tipperary']
# [' dublin 2']
# [' wexford']
# [' frankfield']
# [' co. galway']
# [' balbriggan']
# [' cork']
# [' phibsboro']
# [' cavendish lane']
# [' county donegal']
# [' cabinteely']
# [' wexford']
# [' dublin 24']
# [' tyrrelstown']
# [' tullamore']
# [' carrick on shannon']
# [' dublin 8']
# [' jigginstown']
# [' dublin 14']
# [' portlaoise']
# [' navan']
# [' manorhamilton']
# [' rathnew']
# [' lifford']
# [' tipperary']
# [' co cork']
# [' tipperary']
# [' athlone']
# [' navan']
# [' galway']
# [' baylin']
# [' co. dublin']
# [' cloughjordan']
# [' blackrock']
# [' cork']
# [' dublin 7']
# [' co wicklow']
# [' wexford']
# [' cork']
# [' wexford']
# [' dublin 4']
# [' tipperary']
# [' dublin 6']
# [' killaloe']
# [' clonakilty']
# [' dublin']
# [' dublin 7']
# [' donegal']
# [' baldoyle dublin 13']
# [' kildare']
# [' nenagh']
# [' claremorris']
# [' lucan']
# [' dublin 15']
# [' dublin 24']
# [' claremorris']
# [' louth']
# [' waterford']
# [' cavan']
# [' kilcoole']
# [' portarlington']
# [' wexford']
# [' offaly']
# [' athlone']
# [' fermoy']
# [' ballingarry']
# [' dublin']
# [' sandyford']
# [' dooradoyle']
# [' ennis']
# [' adamstown']
# [' cork']
# [' carrick on shannon']
# [' ballyjamesduff']
# [' portnablagh']
# [' waterford']
# [' ennis']
# [' limerick']
# [' leixlip']
# [' dalkey']
# [' co. cork']
# [' castleknock']
# [' dublin 5']
# [' castleconnell']
# [' sligo']
# [' scallagheen']
# [' maree road']
# [' nenagh']
# [' bettystown']
# [' ballybunion']
# [' glenealy']
# [' waterford']
# [' tipperary']
# [' clondalkin']
# [' county roscommon']
# [' bantry']
# [' tipperary']
# [' slane']
# [' dublin d14 x654']
# [' sandyford dublin 18']
# [' waterford']
# [' dublin 15']
# [' clare']
# [' sydney parade avenue']
# [' cork']
# [' galway']
# [' bundoran']
# [' claremorris']
# [' meath']
# [' dublin 16']
# [' co kerry']
# [' limerick']
# [' kerry']
# [' longford']
# [' enniscrone']
# [' cork']
# [' kildare']
# [' navan']
# [' dublin']
# [' drogheda']
# [' balgriffin']
# [' galway']
# [' cork']
# [' gorey']
# [' bornacoola']
# [' kells']
# [' dublin']
# [' balbriggan']
# [' sandymount']
# [' portmarnock']
# [' porterstown']
# [' shanagarry']
# [' longford']
# [' kildare']
# [' terenure']
# [' meellick']
# [' mullingar']
# [' dublin 2']
# [' tallow']
# [' dublin 16']
# [' galway']
# [' limerick']
# [' drimnagh']
# [' knocklyon']
# [' cork']
# [' cork']
# [' newcastle west']
# [' sligo']
# [' rathmore']
# [' co carlow']
# [' louth']
# [' co wexford']
# [' castletroy']
# [' dublin 7']
# [' westmeath']
# [' clonakilty']
# [' mallow']
# [' dublin 1']
# [' convent garden  kinsale']
# [' county limerick']
# [' cork']
# [' co cork']
# [' castlebar']
# [' 31 - 32 cumberland st']
# [' kilashee']
# [' county cork']
# [' monkstown']
# [' cavan']
# [' tipperary']
# [' cork']
# [' kildare']
# [' dublin 7']
# [' middleton']
# [' charleville']
# [' tralee']
# [' poulacurry']
# [' kildare']
# [' mayo']
# [' waterford']
# [' somerville avenue']
# [' meath']
# [' co. donegal']
# [' wicklow']
# [' ranelagh']
# [' youghal']
# [' kilkenny']
# [' limerick city']
# [' sandymount avenue']
# [' dublin 8']
# [' pembrokestown']
# [' tralee']
# [' ringsend dublin 4']
# [' dundalk']
# [' co. sligo']
# [' youghal']
# [' dublin 9']
# [' donadea']
# [' waterville']
# [' kildare']
# [' co cork']
# [' dublin 16']
# [' donegal']
# [' ballyfermot']
# [' meath']
# [' kells']
# [' druid valley dublin 18']
# [' dublin 4']
# [' cork']
# [' clontarf']
# [' co cork']
# [' athy']
# [' sandycove']
# [' co kildare']
# [' co galway']
# [' galway']
# [' ballyconnell']
# [' athlone']
# [' co kerry']
# [' lucan']
# [' renmore']
# [' offaly']
# [' kilkenny']
# [' co. laois']
# [' dublin 8']
# [' an rinn']
# [' cork']
# [' dublin']
# [' crosshaven']
# [' roscommon']
# [' stillorgan']
# [' swords']
# [' kenmare']
# [' dublin 7']
# [' donohill']
# [' kerry']
# [' swords']
# [' naas']
# [' wicklow']
# [' buncrana']
# [' cork']
# [' waterford']
# [' gleneely']
# [' dublin']
# [' county mayo']
# [' bailieborough']
# [' ballyhale']
# [' waterford']
# [' glountane']
# [' navan']
# [' malahide']
# [' brownshill']
# [' galway']
# [' balbriggan']
# [' kildare']
# [' portlaoise']
# [' athlone']
# [' kilcolgan']
# [' blackrock']
# [' kilcar']
# [' dublin']
# [' carrick-on-shannon']
# [' co dublin']
# [' new ross']
# [' tralee']
# [' abbeyleix']
# [' portlaoise']
# [' sutton dublin 13']
# [' co galway']
# [' portmarnock']
# [' donabate']
# [' clay farm']
# [' waterford city']
# [' dublin']
# [' co. leitrim']
# [' county dublin']
# [' dublin 15']
# [' meath']
# [' galway']
# [' louth']
# [' co cavan']
# [' co waterford']
# [' galway']
# [' athenry']
# [' kildare']
# [' co meath']
# [' waterford']
# [' dublin 15']
# [' drumlish']
# [' dunmore rd']
# [' co. leitrim']
# [' blackrock']
# [' clondalkin dublin 22']
# [' midleton']
# [' clonshaugh dublin 17']
# [' dublin 16']
# [' leopardstown heights']
# [' ashbourne']
# [' mayo']
# [' rahoon']
# [' donegal']
# [' dundalk']
# [' carlow']
# [' co monaghan']
# [' cavan']
# [' county dublin']
# [' tynagh']
# [' attirory']
# [' duleek']
# [' co waterford']
# [' co. wicklow']
# [' greystones']
# [' howth']
# [' rathmines']
# [' co kildare']
# [' kilmovee']
# [' dublin 15']
# [' dublin 4']
# [' co monaghan']
# [' artane dublin 5']
# [' ballycullen  dubin 24']
# [' kilkenny']
# [' city west']
# [' waterford']
# [' co tipperary']
# [' dublin 9']
# [' kilkenny']
# [' balbriggan']
# [' galway']
# [' dublin 10']
# [' dublin']
# [' limerick']
# [' co leitrim']
# [' dublin 16']
# [' galway']
# [' kilcock']
# [' dublin']
# [' kilkee']
# [' mallow']
# [' newbridge']
# [' mungret']
# [' letterkenny']
# [' ashford']
# [' castlebellingham']
# [' lucan']
# [' dublin 7']
# [' waterford']
# [' navan']
# [' carrick on shannon']
# [' dublin 15']
# [' dublin']
# [' wexford']
# [' carrigaline']
# [' castlebridge']
# [' ballina']
# [' malahide']
# [' county wicklow']
# [' station road']
# [' co monaghan']
# [' dromahaire']
# [' co galway']
# [' crumlin']
# [' wicklow']
# [' ashtown']
# [' sligo']
# [' lusk']
# [' co. sligo']
# [' finglas']
# [' co dublin']
# [' camolin']
# [' dublin']
# [' gorey']
# [' co westmeath']
# [' sligo']
# [' kildare town']
# [' rathfarnham']
# [' dublin 5']
# [' tipperary']
# [' lucan']
# [' co kildare']
# [' co. kildare']
# [' enniscrone']
# [' gorey']
# [' dublin 22']
# [' killiney']
# [' claregalway']
# [' mayo']
# [' galway']
# [' co clare']
# [' mallow']
# [' 302 south circular road']
# [' athlone']
# [' sandyford']
# [' castleblayney']
# [' galway']
# [' county cork']
# [' ballinteer dublin 16']
# [' co wexford']
# [' blessington']
# [' co galway']
# [' meath']
# [' dunshaughlin']
# [' garraneagh']
# [' mayo']
# [' dublin 3']
# [' co clare']
# [' loughrea']
# [' portmarnock']
# [' naas']
# [' billis']
# [' dublin 5']
# [' meath']
# [' ferns']
# [' dublin']
# [' co dublin']
# [' donegal']
# [' dublin']
# [' charleville']
# [' dublin 13']
# [' bennettsbridge']
# [' dublin 6']
# [' maynooth']
# [' kildare']
# [' co kerry']
# [' lucan']
# [' dublin 5']
# [' kilcock']
# [' cork']
# [' drumcondra']
# [' dublin 15']
# [' castlebar']
# [' cork']
# [' dublin 7']
# [' maynooth']
# [' birr']
# [' louth']
# [' athlone']
# [' tuam']
# [' kildysart']
# [' cork']
# [' tipperary']
# [' co westmeath']
# [' herberton  rialto']
# [' laois']
# [' stillorgan']
# [' friar street']
# [' sallins']
# [' co cavan']
# [' dublin 11']
# [' kilkenny']
# [' county dublin']
# [' navan road']
# [' castleknock']
# [' carlow']
# [' co. cork']
# [' cootehill']
# [' tallaght']
# [' meath']
# [' meath']
# [' whitehall road']
# [' dublin 15']
# [' ballinasloe']
# [' co kerry']
# [' wicklow']
# [' kildimo']
# [' bettystown']
# [' rathcoole']
# [' tramore']
# [' donnybrook']
# [' meath']
# [' kells']
# [' westmeath']
# [' dundalk']
# [' tramore']
# [' limerick']
# [' clare']
# [' dublin 11']
# [' gorey']
# [' killarney']
# [' donaghmede']
# [' mungret']
# [' dundalk']
# [' upper glenageary road']
# [' westmeath']
# [' tralee']
# [' portlaoise']
# [' dublin']
# [' raheny dublin 5']
# [' donegal']
# [' dublin 6']
# [' co westmeath']
# [' dublin 15']
# [' delgany']
# [' dublin 5']
# [' waterford']
# [' county sligo']
# [' navan']
# [' ballingarry']
# [' santry']
# [' dublin 7']
# [' wexford']
# [' dunboyne']
# [' limerick']
# [' swords']
# [' navan']
# [' newport']
# [' boyle']
# [' limerick']
# [' waterford']
# [' kilshanny']
# [' newbridge']
# [' sligo']
# [' enniscorthy']
# [' county limerick']
# [' cork']
# [' longford']
# [' carlow']
# [' barnwell']
# [' lucan']
# [' dublin 24']
# [' sandyford']
# [' galway']
# [' kilrush']
# [' enfield']
# [' coolaney']
# [' galway']
# [' dublin']
# [' tramore']
# [' ballina']
# [' rosslare harbour']
# [' limerick']
# [' kildare']
# [' dublin 12']
# [' crumlin']
# [' dublin 18']
# [' kildare']
# [' co sligo']
# [' loughlion']
# [' killybegs']
# [' asbourne']
# [' dublin 14']
# [' castlebar']
# [' kildare']
# [' cork']
# [' clontarf']
# [' cork']
# [' cork']
# [' glenamuck rd']
# [' rathconrath']
# [' co. sligo']
# [' kilmallock']
# [' navan']
# [' kilkenny']
# [' cork']
# [' enniscorthy']
# [' cork']
# [' dublin 12']
# [' dingle']
# [' wexford']
# [' dublin 10']
# [' cork']
# [' roscommon']
# [' laois']
# [' kilmessan']
# [' ballina']
# [' turners cross']
# [' bandon']
# [' co monaghan']
# [' enniscorthy']
# [' kildare']
# [' portsalon']
# [' upper glenageary road']
# [' donabate']
# [' co dublin']
# [' castleknock']
# [' tivoli']
# [' offaly']
# [' blackrock']
# [' foxrock dublin 18']
# [' dublin 22']
# [' dun laoghaire']
# [' meath']
# [' dalkey']
# [' donegal']
# [' kildare']
# [' co mayo']
# [' kilcock']
# [' rathnew']
# [' navan']
# [' wexford']
# [' county leitrim']
# [' co sligo']
# [' blessington']
# [' thomas davis street west']
# [' kildare']
# [' letterkenny']
# [' nenagh']
# [' quinagh']
# [' aikens village']
# [' dublin 14']
# [' dublin 1']
# [' newbridge']
# [' dublin']
# [' dublin']
# [' donegal']
# [' ballyhaunis']
# [' co longford']
# [' athlumney']
# [' cloyne']
# [' tullamore']
# [' carrick road']
# [' dublin 8']
# [' templeogue']
# [' portarlington']
# [' ratoath']
# [' dublin 6w']
# [' kilcullen road']
# [' mallow']
# [' dublin 11']
# [' co clare']
# [' co offaly']
# [' dock rd']
# [' castleknock dublin 15']
# [' co limerick']
# [' swords']
# [' fourmilehouse']
# [' mullingar']
# [' dublin 15']
# [' ballinahowen']
# [' cork']
# [' geevagh']
# [' dublin 10']
# [' malahide road']
# [' kildare']
# [' county donegal']
# [' cork']
# [' inishowen']
# [' co. dublin']
# [' carrickmacross']
# [' killarney']
# [' williamstown']
# [' donegal']
# [' mullingar']
# [' galway']
# [' dublin']
# [' straffan']
# [' terenure']
# [' cootehill']
# [' waterford']
# [' dublin 2']
# [' mullingar']
# [' leopardstown dublin 1']
# [' woodford']
# [' clonee']
# [' blarney']
# [' sligo']
# [' carlow']
# [' donegal']
# [' ballina']
# [' co cork']
# [' naas']
# [' bantry']
# [' saggart']
# [' limerick']
# [' sligo']
# [' dublin 10']
# [' galway']
# [' dublin 24']
# [' kildare']
# [' killarney']
# [' enfield']
# [' balbriggan']
# [' waterford']
# [' portmarnock']
# [' ballinlough']
# [' co wicklow']
# [' dublin']
# [' blackrock']
# [' donabate']
# [' athy']
# [' cork']
# [' wicklow town']
# [' dublin 3']
# [' loch garman']
# [' kilkenny']
# [' dublin 18']
# [' tralee']
# [' dublin']
# [' malahide road']
# [' new priory']
# [' co offaly']
# [' dublin 5']
# [' co mayo']
# [' killaloe']
# [' sandyford dublin 18']
# [' ennis']
# [' leitrim']
# [' tyrellstown']
# [' blackrock']
# [' co. westmeath']
# [' co. limerick']
# [' westmeath']
# [' park view']
# [' cork']
# [' county tipperary']
# [' carrick on shannon']
# [" harold's cross"]
# [' ashtown']
# [' drogheda']
# [' malahide']
# [' dublin 15']
# [' dublin 24']
# [' letterkenny']
# [' gorey']
# [' dublin 9']
# [' dublin']
# [' kerry']
# [' dublin 9']
# [' banagher']
# [' kilkenny']
# [' co wicklow']
# [' killarney']
# [' co. galway']
# [' tipperary']
# [' galway']
# [' rathborne']
# [' deans grange']
# [' dunshaughlin']
# [' killarney']
# [' thomastown']
# [' westmeath']
# [' wexford']
# [' leitrim']
# [' dunboyne']
# [' station rd']
# [' edenderry']
# [' portlaoise']
# [' county cork']
# [' donabate']
# [' dublin 24']
# [' dublin 15']
# [' carriganarra']
# [' clonskeagh']
# [' cork']
# [' louth']
# [' ballinasloe']
# [' dublin']
# [' co donegal']
# [' kildare']
# [' county cork']
# [' letterkenny']
# [' wexford']
# [' co. cork']
# [' ridge road portlaoise']
# [' main st']
# [' dublin 4']
# [' limerick']
# [' dundalk']
# [' co cork']
# [' tallaght']
# [' enniscorthy']
# [' county longford']
# [' wilton']
# [' co wexford']
# [' kildare']
# [' dublin 5']
# [' ballinamore']
# [' athy']
# [' tralee']
# [' co cork']
# [' dublin 14']
# [' longford']
# [' donegal']
# [' laois']
# [' new ross']
# [' newbridge']
# [' louth']
# [' dublin 6']
# [' carlingford']
# [' glasnevin']
# [' co kerry']
# [' co longford']
# [' terenure']
# [' wicklow']
# [' dublin7']
# [' co limerick']
# [' dublin 18']
# [' dublin 15']
# [' ballsbridge']
# [' galway']
# [' co. limerick']
# [' athlacca']
# [' galway']
# [' sligo']
# [' offaly']
# [' balbriggan']
# [' cork']
# [' dublin']
# [' tullow']
# [' armagh road']
# [' castlebridge']
# [' ballybride road']
# [' waterford']
# [' waterford']
# [' carpenterstown']
# [' barna']
# [' monaghan']
# [' inchicore']
# [' westport']
# [' donegal']
# [' wicklow']
# [' laois']
# [' lecamy']
# [' tullow rd']
# [' straffan']
# [' dublin 3']
# [' glanmire']
# [' carrignafoy']
# [' dublin 18']
# [' lucan']
# [' clonmacken']
# [' mallow']
# [' douglas']
# [' lifford']
# [' dublin']
# [' woodford wheaton hall dublin road']
# [' dublin16']
# [' dunmanway']
# [' avoca']
# [' co cavan']
# [' co. galway']
# [' ennis']
# [' ballydowney']
# [' renmore']
# [' dublin 2']
# [' kilkenny']
# [' castleblayney']
# [' dublin 7']
# [' dublin 5']
# [' dublin 8']
# [' ballsbridge']
# [' sandyford']
# [' limerick']
# [' knockvicar']
# [' dundrum']
# [' cork']
# [' crossagalla']
# [' cork']
# [' dublin 4']
# [' charleville']
# [' monkstown']
# [' carlow']
# [' dublin 7']
# [' dundalk']
# [' roscommon']
# [' dyer st']
# [' castleblayney']
# [' waterford']
# [' cork']
# [' carrigtwohill']
# [' skerries']
# [' cork']
# [' dublin 5']
# [' maynooth']
# [' tipperary']
# [' cork']
# [' achill']
# [' cabinteely']
# [' kildare']
# [' killucan']
# [' athlone']
# [' kenmare']
# [' limerick']
# [' newbridge']
# [' carlow']
# [' dublin 9']
# [' galway city']
# [' wexford']
# [' kilkenny']
# [' tallaght']
# [' kilcock']
# [' county dublin']
# [' stocking avenue']
# [' bray']
# [' station road']
# [' mallow']
# [' wicklow']
# [' thurles']
# [' bray']
# [' dublin 15']
# [' limerick']
# [' meath']
# [' finglas']
# [' celbridge']
# [' co kildare']
# [' corbally']
# [' craughwell']
# [' bray']
# [' navan']
# [' cork']
# [' clane']
# [' lucan']
# [' offaly']
# [' leopardstown']
# [' rochestown']
# [' hawkfield']
# [' cork']
# [' castlefin']
# [' dublin 15']
# [' dublin 11']
# [' westmeath']
# [' county roscommon']
# [' clonsilla']
# [' santry dublin 9']
# [' monaghan']
# [' fethard']
# [' rathfarnham gate']
# [' balgriffin']
# [' greystones']
# [' limerick']
# [' monaghan']
# [' athenry']
# [' drogheda']
# [' royal canal park  ratoath rd']
# [' galway']
# [' kildare']
# [' co laois']
# [' dublin 10']
# [' athlone']
# [' lisduff']
# [' adamstown']
# [' lucan']
# [' malahide']
# [' dublin']
# [' new ross']
# [' adare']
# [' leighlinbridge']
# [' waterford']
# [' dublin 7']
# [' tallaght dublin 24']
# [' sandymount']
# [' newbridge']
# [' waterford']
# [' navan']
# [' midleton']
# [' dundalk']
# [' ballycanew']
# [' dundalk']
# [' navan road']
# [' killarney']
# [' meath']
# [' santry']
# [' ballymote']
# [' mullingar']
# [' kerry pike']
# [' co kerry']
# [' enniscorthy']
# [' dublin 12']
# [' gweedore']
# [' kilcavan upper']
# [' meath']
# [' croom']
# [' laois']
# [' dublin 7']
# [' cork']
# [' dublin 4']
# [' ballyboden dublin 16']
# [' tallaght dublin 24']
# [' limerick']
# [' roscommon']
# [' galway']
# [' limerick']
# [' kilcock']
# [' tipperary']
# [' laois']
# [' wexford']
# [' north city link rd']
# [' sligo']
# [' co laois']
# [' galway']
# [' enniscorthy wexford']
# [' kildare']
# [' dublin']
# [' castlemahon']
# [' mallow']
# [' cork']
# [' co cork']
# [' gorey']
# [' dungarvan']
# [' monaghan']
# [' kildare']
# [' westmeath']
# [' athlone']
# [' ashtown']
# [' roscommon']
# [' galway']
# [' kildare']
# [' athlone']
# [' ballyvolane cork']
# [' castleknock dublin 15']
# [' cootehill']
# [' dublin 16']
# [' carrigaline']
# [' dublin 18']
# [' charlestown - finglas']
# [' cork']
# [' cork']
# [' saggart dublin 24']
# [' cork']
# [' county tipperary']
# [' dublin 5']
# [' sligo']
# [' dublin']
# [' limerick']
# [' laois']
# [' dungarvan']
# [' dublin 18']
# [' mallow']
# [' galway']
# [' strandhill']
# [' louisburgh']
# [' lucan']
# [' dublin 6']
# [' drogheda']
# [' dublin 3']
# [' co kildare']
# [' celbridge']
# [' wicklow town']
# [' cahir']
# [' minanes bridge']
# [' ballymote']
# [' finglas dublin 11']
# [' dublin 7']
# [' cavan']
# [' co roscommon']
# [' hansfield']
# [' dublin']
# [' enniscorthy']
# [' ballyvolane']
# [' dun laoghiare']
# [' hansfield']
# [' gorey']
# [' mullingar']
# [' limerick']
# [' county offaly']
# [' cork']
# [' santry dublin 9']
# [' cashel']
# [' dublin']
# [' enniscorthy']
# [' edenderry']
# [' drynam hall kinsealy dublin']
# [' galway']
# [' clane']
# [' dublin']
# [' clonsilla dublin 15']
# [' midleton']
# [' co.dublin']
# [' dublin 14']
# [' naas']
# [' kerry']
# [' tipperary']
# [' county westmeath']
# [' dublin 24']
# [' commons rd']
# [' castlebellingham']
# [' citywest']
# [' carrickmines']
# [' dublin 9']
# [' portarlington']
# [' mount merrion']
# [' marlton road']
# [' cork']
# [' ballinrobe']
# [' bray']
# [' wexford']
# [' dublin']
# [' limerick']
# [' ballinlough']
# [' dublin 4']
# [' co.meath']
# [' achill island']
# [' wexford']
# [' dublin']
# [' wexford']
# [' kerry']
# [' dublin 15']
# [' dublin 12']
# [' county cork']
# [' ballyvolane']
# [' clonlara']
# [' dun laoghaire']
# [' conyngham road']
# [' limerick']
# [' meath']
# [' longford']
# [' maldron road']
# [' edenderry']
# [' portumna']
# [' ballygarvan']
# [' donnybrook']
# [' mayo']
# [' limerick']
# [' limerick']
# [' blanchardstown dublin 15']
# [' newbridge']
# [' sandyford dublin 18']
# [' thonlagee']
# [' ballina']
# [' killarney']
# [' moycullen']
# [' portlaoise']
# [' cork']
# [' gorey']
# [' tipperary town']
# [' lucan']
# [' thurles']
# [' kilnamanagh']
# [' waterford']
# [' lucan']
# [' limerick']
# [' galway']
# [' glasnevin dublin 9']
# [' ballinasloe']
# [' dublin 12']
# [' lahinch']
# [' cork']
# [' co. wexford']
# [' ringsend dublin 4']
# [' clogheen']
# [' castledermot']
# [' greenmount']
# [' donegal']
# [' edgeworthstown']
# [' tallaght']
# [' offaly']
# [' mallow']
# [' mullingar']
# [' dooradoyle']
# [' tralee']
# [' dublin']
# [' ifsc dublin 1']
# [' dublin 1']
# [' midleton']
# [' dun laoghaire']
# [' town car park']
# [' dublin']
# [' kilkenny']
# [' cork']
# [' navan']
# [' kilkenny']
# [' waterford']
# [' co donegal']
# [' offaly']
# [' clonmel']
# [' rose hill']
# [' rosslare strand']
# [' louth']
# [' meath']
# [' dublin 7']
# [' limerick']
# [' galway']
# [' strand rd']
# [' greenville lane']
# [' co cork']
# [' city gate']
# [' railway st dublin 1']
# [' miltown malbay']
# [' portlaoise']
# [' co roscommon']
# [' kilkenny']
# [' birr']
# [' athy']
# [' co wicklow']
# [' kilkenny']
# [' bruree']
# [' mullingar']
# [' clonmel']
# [' donabate']
# [' dundalk']
# [' kilkenny']
# [' glengarriff']
# [' kenmare']
# [' clarinbridge']
# [' ashford']
# [' howth']
# [' co longfors']
# [' co galway']
# [' newbridge']
# [' tipperary']
# [' cavan']
# [' drimoleague']
# [' galway']
# [' chapelizod']
# [' dublin']
# [' cavan']
# [' tipperary']
# [' drogheda']
# [' carrigtwohill']
# [' co leitrim']
# [' drogheda']
# [' dublin 12']
# [' finglas']
# [' county kerry']
# [' shanakiel']
# [' dromod']
# [' dublin 14']
# [' clongriffin']
# [' louth']
# [' bandon']
# [' donegal']
# [' co.roscommon']
# [' kildare']
# [' meath']
# [' dublin 9']
# [' dublin 9']
# [' co cork']
# [' co cork']
# [' dublin 10']
# [' galway']
# [' rathcoole']
# [' roscommon']
# [' kielduff']
# [' stillorgan']
# [' leenaun']
# [' oranmore']
# [' summerhill']
# [' tallaght dublin 24']
# [' ballaghaderreen']
# [' dublin 22']
# [' dublin 7']
# [' sneem']
# [' douglas']
# [' bandon']
# [' ennis']
# [' carlow']
# [' limerick']
# [' cavan']
# [' blacklion']
# [' foxrock']
# [' barraduff  killarney']
# [' ballincollig']
# [' county kerry']
# [' wexford']
# [' portmagee']
# [' dublin']
# [' craddockstown']
# [' donoughmore']
# [' glasnevin']
# [' co. dublin']
# [' ringsend']
# [' clongriffin']
# [' dublin 1']
# [' tralee']
# [' athlone']
# [' kildare']
# [' midleton']
# [' county limerick']
# [' salthill']
# [' cork']
# [' wicklow']
# [' tipperary']
# [' drogheda']
# [' malahide']
# [' county dublin']
# [' ballina']
# [' castleknock dublin 15']
# [' dublin 8']
# [' dublin 4']
# [' dublin 15']
# [' main st']
# [' avoca']
# [' clare']
# [' ballsbridge dublin 4']
# [' dublin']
# [' dublin 1']
# [' kilcock']
# [' kilmallock']
# [' dublin 22']
# [' waterford']
# [' rathfarnham']
# [' castleknock']
# [' roscommon']
# [' dublin']
# [' co leitrim']
# [' kilworth']
# [' youghal']
# [' ballybrack']
# [' clontarf dublin 3']
# [' cork']
# [' nenagh']
# [' galway']
# [' rathcormac']
# [' skerries']
# [' blanchardstown']
# [' dublin']
# [' graiguecullen']
# [' clare']
# [' dublin 6']
# [' ennis']
# [' co. wexford']
# [' terryland galway']
# [' killarney']
# [' gorey']
# [' blackrock']
# [' bettystown']
# [' crosshaven']
# [' galway']
# [' balgriffin']
# [' thomastown']
# [' co. sligo']
# [' naas']
# [' galway']
# [' dublin road']
# [' co. wicklow']
# [' kenagh']
# [' bangor erris']
# [' dublin 6']
# [' waterford']
# [' citywest dublin 24']
# [' straffan']
# [' offaly']
# [' barna']
# [' galway']
# [' cavan']
# [' dublin 2']
# [' kildare']
# [' farranlea road']
# [' dungarvan']
# [' kilkenny']
# [' sligo']
# [' dublin 3']
# [' poppinjtree']
# [' co dublin']
# [' mullingar']
# [' limerick']
# [' tipperary']
# [' dublin 10']
# [' castletroy']
# [' parcnagowan']
# [' carrigtwohill']
# [' roscam']
# [' dundalk']
# [' westmeath']
# [' model farm rd']
# [' lahinch']
# [' dunkettle']
# [' co.cork']
# [' co wexford']
# [' bailieborough']
# [' kerry']
# [' sligo']
# [' offaly']
# [' dublin 6w']
# [' limerick']
# [' limerick']
# [' coolock']
# [' dublin 6']
# [' dublin 6w']
# [' co cork']
# [' dublin 15']
# [' cork']
# [' co. cavan']
# [' renmore']
# [' waterford']
# [' newtowngore']
# [' portlaoise']
# [' tipperary']
# [' co. cork']
# [' letterkenny']
# [' glasnevin']
# [' bray']
# [' dublin 7']
# [' co. dublin']
# [' terenure']
# [' athy']
# [' shankill']
# [' kildare']
# [' co galway']
# [' county longford']
# [' wicklow']
# [' upper leeson st']
# [' piltown']
# [' dublin 4']
# [' ratoath']
# [' glasheen']
# [' ballina']
# [' cavan']
# [' terenure']
# [' castleblaney']
# [' dublin 24']
# [' cork']
# [' fethard']
# [' gorey wexford']
# [' wexford']
# [' naul']
# [' dublin']
# [' co kildare']
# [' granges road']
# [' newtownmountkennedy']
# [' letterkenny']
# [' county westmeath']
# [' glasnevin']
# [' douglas']
# [' cork']
# [' kilcullen']
# [' sandyford']
# [' leitrim']
# [' tullamore']
# [' donegal']
# [' dublin 24']
# [' cobh']
# [' galway']
# [' cork']
# [' new building lane']
# [' dublin']
# [' dublin 3']
# [' listowel']
# [' dublin 9']
# [' clontarf']
# [' cork']
# [' rochestown road']
# [' wicklow']
# [' galway']
# [' dublin']
# [' grace park road']
# [' dunmore']
# [' donegal']
# [' cork']
# [' co clare']
# [' ballymore']
# [' cork']
# [' trim']
# [' nenagh']
# [' carlow']
# [' tallaght']
# [' ongar dublin 15']
# [' passage west']
# [' co. waterford']
# [' ballina']
# [' kildare']
# [' bettystown']
# [' cobh']
# [' enniscorthy']
# [' cavan']
# [' glanmire']
# [' wexford']
# [' letterkenny']
# [' ballyhaunis']
# [' co mayo']
# [' kilkenny']
# [' laytown']
# [' terenure']
# [' lucan']
# [' co clare']
# [' dublin 2']
# [' manorhamilton']
# [' cork']
# [' cobh']
# [' dublin']
# [' clare']
# [' cabinteely']
# [' dublin 5']
# [' portlaoise']
# [' booterstown']
# [' co. donegal']
# [' co donegal']
# [' dublin 6']
# [' clare']
# [' ennis road']
# [' ashbourne']
# [' co donegal']
# [' farnham']
# [' galway']
# [' churchtown']
# [' crannagh']
# [' meath']
# [' carrig']
# [' dublin 11']
# [' midleton']
# [' milltown']
# [' galway']
# [' casleknock dublin 15']
# [' thurles']
# [' rathfarnham dublin 14']
# [' dublin']
# [' castlerea']
# [' galway']
# [' skerries']
# [' roundwood']
# [' louth']
# [' dublin 10']
# [' kells']
# [' tralee']
# [' meath']
# [' swords road']
# [' glasnevin dublin 11']
# [' dublin 9']
# [' new ross']
# [' kildare']
# [' carrigaline']
# [' naas']
# [' athenry']
# [' ballyconnell']
# [' athlumney']
# [' killybegs']
# [' kildare']
# [' foxrock']
# [' cashel']
# [' bundoran']
# [' blackrock']
# [' dublin 6w']
# [' roscommon']
# [' castleknock']
# [' co cavan']
# [' galway']
# [' montenotte']
# [' blanchardstown']
# [' cork']
# [' tullamore']
# [' meath']
# [' cork']
# [' donegal']
# [' naas']
# [' tipperary']
# [' clontarf dublin 3']
# [' mayo']
# [' firhouse']
# [' fermoy']
# [' golf links road']
# [' co offaly']
# [' sandyford']
# [' tuam']
# [' offaly']
# [' maynooth']
# [' dublin 18']
# [' co waterford']
# [' cortoon']
# [' co donegal']
# [' navan']
# [' meath']
# [' leeson park']
# [' navan']
# [' adamstown  lucan']
# [' clonskeagh dublin 14']
# [' dublin 4']
# [' cork']
# [' collinstown']
# [' kilmallock']
# [' kilrush']
# [' wicklow']
# [' dublin']
# [' co dublin']
# [' south circular road']
# [' portlaoise']
# [' dungarvan']
# [' roscommon']
# [' tullamore']
# [' dublin 16']
# [' killarney']
# [' coolock dublin 17']
# [' ashbourne']
# [' co galway']
# [' drogheda']
# [' gaultier']
# [' galway']
# [' dalkey']
# [' dublin']
# [' waterford']
# [' laois']
# [' lissarda']
# [' artane']
# [' dublin 16']
# [' dublin 1']
# [' cabinteely dublin 18']
# [' clare']
# [' waterford']
# ...
# [' cork']
# [' carrigaline']
# [' boyle roscommon']
# [' roscommon']
# [' drogheda']
# [' shannon']
# [' youghal']
# [' co. kildare']
# [' tramore']
# [' scramogue']
# [' slaney']
# [' roscrea']
# [' sutton']
# [' kildare']
# [' waterford']
# [' kildare']
# [' co tipperary']
# [' kilcock']
# [' clonmel']
# [' charlotte quay']
# [' rosslare harbour']
# [' hugginstown']
# [' carlow']
# [' cork']
# [' dublin']
# [' orwell road  rathgar']
# [' milltown']
# [' waterford']
# [' tipperary']
# [' clonsilla dublin 15']
# [' mungret']
# [' wexford']
# [' mallow']
# [' baldoyle']
# [' dublin']
# [' westport']
# [' swords']
# [' waterford']
# [' kilkenny']
# [' moycullen']
# [' county kildare']
# [' cork']
# [' ballinasloe']
# [' dun laoghaire dublin 18']
# [' dublin 5']
# [' waterford']
# [' roscommon']
# [' dublin 14']
# [' dublin']
# [' naas']
# [' tipperary']
# [' riverstick']
# [' dublin']
# [' dublin']
# [' ranelagh']
# [' athboy']
# [' killarney']
# [' sandyford']
# [' dunshaughlin']
# [' lucan']
# [' waterford']
# [' leitrim']
# [' tipperary']
# [' main st']
# [' thurles']
# [' mullagh']
# [' drumahair']
# [' dublin 14']
# [' little island']
# [' glenageary']
# [' duleek']
# [' meath']
# [' glanmire']
# [' co. dublin']
# [' kildare']
# [' cork']
# [' kildare']
# [' robswall']
# [' letterkenny']
# [' county louth']
# [' dublin 12']
# [' kilkenny']
# [' forrest road']
# [' castleknock']
# [' athlone']
# [' mullingar']
# [' marina village  greystones']
# [' new ross']
# [' bandon']
# [' ashbourne']
# [' upper leeson street']
# [' brittas bay']
# [' conyngham rd dublin 8']
# [' castletroy']
# [' clarecastle']
# [' offaly']
# [' raheny']
# [' new ross']
# [' galway city']
# [' county louth']
# [' limerick']
# [' wicklow']
# [' wicklow']
# [' enfield']
# [' dublin 12']
# [' county donegal']
# [' westmeath']
# [' dun laoghaire']
# [' glanmire']
# [' newbridge']
# [' dublin 16']
# [' cork']
# [' scholarstown road']
# [' kildare']
# [' knocklyon']
# [' cork']
# [' tulla rd']
# [' leixlip']
# [" quigley's point"]
# [' ranelagh']
# [' tralee']
# [' dublin 15']
# [' limerick']
# [' dublin 11']
# [' co limerick']
# [' clonakilty']
# [' carlow']
# [' dublin']
# [' clare']
# [' rosslare']
# [' annacotty']
# [' kilkenny']
# [' dublin 5']
# [' co galway']
# [' newcastle west']
# [' westbourne rise dublin 22']
# [' goatstown']
# [' westmeath']
# [' wexford']
# [' county limerick']
# [' dublin 8']
# [' westport']
# [' roscam']
# [' kildare']
# [' killucan']
# [' athlone']
# [' pallasgreen']
# [' cootehill']
# [' lifford']
# [' finglas']
# [' thomastown']
# [' sligo town']
# [' dun laoghaire']
# [' mallow']
# [' co laois']
# [' dublin']
# [' ballyvalley']
# [' balintglass']
# [' kilkenny']
# [' dublin 20']
# [' south circular rd']
# [' wicklow']
# [' kinnitty']
# [' galway']
# [' balgriffin']
# [' dublin 24']
# [' rosslare harbour']
# [' st. margarets']
# [' rathbeg']
# [' tallaght']
# [' dun laoghaire']
# [' ballyhaunas']
# [' dublin 15']
# [' dublin 3']
# [' kildare']
# [' galway']
# [' roscommon']
# [' mayo']
# [' passage west']
# [' dublin 24']
# [' louth']
# [' dublin']
# [' dublin']
# [' ballymahon']
# [' meath']
# [' galway']
# [' dublin 09']
# [' county kiildare']
# [' north kings street']
# [' co waterford']
# [' dublin']
# [' kilmallock']
# [' dublin 11']
# [' dublin']
# [' mill road']
# [' dublin 10']
# [' donegal']
# [' cork']
# [' dundalk']
# [' howth']
# [' mayo']
# [' dundrum']
# [' wexford']
# [' dublin 7']
# [' hansfield']
# [' douglas']
# [' balbriggan']
# [' blackrock']
# [' ballymote']
# [' dublin']
# [' dublin 11']
# [' tralee']
# [' monaghan']
# [' borrisokane road']
# [' wexford']
# [' castleknock']
# [' dublin 7']
# [' mayor st dublin 1']
# [' galway']
# [' macroom']
# [' dublin']
# [' wexford']
# [' salthill']
# [' ballyfermot']
# [' lismore']
# [' castleknock  dublin 15.']
# [' mayo']
# [' dublin 14']
# [' dublin']
# [' artane']
# [' dublin 1']
# [' greystones']
# [' claremorris']
# [' dublin 5']
# [' co cork']
# [' longford']
# [' dublin 18']
# [' dublin 8']
# [' drumcondra']
# [' dunmore road']
# [' dublin']
# [' leixlip']
# [' kildare']
# [' st columbanus road  dundrum']
# [' douglas']
# [' dublin city']
# [' galway']
# [' galway']
# [' wexford']
# [' croom']
# [' mullingar']
# [' limerick']
# [' ashbourne']
# [' dundalk']
# [' cobh']
# [' meath']
# [' kildare']
# [' dublin 11']
# [' clane']
# [' clarina']
# [' hanover quay']
# [' dublin 1']
# [' cashel']
# [' mallow']
# [' rathfarnham dublin 16']
# [' monaghan']
# [' dublin 7']
# [' dublin 7']
# [' donegal']
# [' annacotty']
# [' cork']
# [' dublin 15']
# [' co cork']
# [' castletroy']
# [' cork']
# [' dundalk']
# [' westport']
# [' westmeath']
# [' midleton']
# [' county tipperary']
# [' dublin 13']
# [' clonmel']
# [' dublin 9']
# [' dublin']
# [' cork']
# [' dublin 15']
# [' co. wicklow']
# [' raheny dublin 5']
# [' lucan']
# [' terenure dublin 6w']
# [' ballybofey']
# [' dublin']
# [' celbridge']
# [' ardee']
# [' monasterevin']
# [' kanturk']
# [' salthill']
# [' newbridge']
# [' dublin']
# [' dundalk']
# [' kilanerin  gorey']
# [' rathmullan']
# [' drumalee  cavan']
# [' fairhill']
# [' ballinamuck']
# [' louth']
# [' dungarvan']
# [' cork']
# [' clane']
# [' bandon']
# [' birr']
# [' dublin 13']
# [' ushers island dublin 8']
# [' hansfield']
# [' crumlin']
# [' youghal']
# [' louth']
# [' foley street']
# [' county cork']
# [' co clare']
# [' tyrellstown']
# [' dublin 11']
# [' templemore']
# [' newcastle']
# [' kells']
# [' kenmare']
# [' lucan']
# [' co longford']
# [' roscommon']
# [' dublin 24']
# [' drogheda']
# [' ballaghaderreen']
# [' new ross']
# [' swords']
# [' waterford']
# [' galway']
# [' dalkey']
# [' monaghan']
# [' galway']
# [' naas']
# [' kildare']
# [' dublin']
# [' dungarvan']
# [' dublin 14']
# [' ballincollig']
# [' maryborough hill']
# [' thurles']
# [' castleknock']
# [' cavan']
# [' dublin']
# [' waterford']
# [' co kilkenny']
# [' sallins']
# [' lucan']
# [' rosslare']
# [' athlone']
# [' glengarriff']
# [' ballincollig']
# [' lettermore']
# [' cork']
# [' malahide']
# [' co. galway']
# [' cork']
# [' rosscarberry']
# [' bundoran']
# [' arklow']
# [' navan']
# [' tyrrellstown']
# [' laois']
# [' dublin']
# [' laois']
# [' tuam']
# [' edenderry']
# [' adamstown']
# [' cork']
# [' dublin 3']
# [' galway']
# [' knocknacarra']
# [' co cork']
# [' wilton']
# [' dublin']
# [' ovens']
# [' wicklow']
# [' kilkenny']
# [' harolds cross dublin 6w']
# [' limerick']
# [' athenry']
# [' cork road']
# [' blackhorse avenue']
# [' leopardstown']
# [' dublin']
# [' dublin 13']
# [' co offaly']
# [' castletreasure']
# [' mitchelstown']
# [' dublin 24']
# [' limerick']
# [' kildare']
# [' co. carlow']
# [' carlow']
# [' dublin 2']
# [' barracks']
# [' dublin 14']
# [' ennis']
# [' wicklow town']
# [' road  finglas  dn147704f']
# [' glasheen rd']
# [' malahide']
# [' naas']
# [' dublin 4']
# [' gweedore']
# [' longford']
# [' laois']
# [' maynooth']
# [' citywest']
# [' youghal']
# [' dublin 16']
# [' co galway']
# [' ranelagh']
# [' cork']
# [' co mayo']
# [' mayo']
# [' portlaoise']
# [' galway']
# [' dromiskin']
# [' cork']
# [' county donegal']
# [' glenamuck rd']
# [' meath']
# [' dublin 4']
# [' dublin']
# [' blackpool']
# [' youghal']
# [' dublin 12']
# [' castlebaldwin']
# [' wexford']
# [' co limerick']
# [' knocknacarra']
# [' navan']
# [' dublin 8']
# [' kildare']
# [' co westmeath']
# [' waterfall avenue']
# [' blackrock']
# [' drogheda']
# [' summerhill']
# [' blackrock']
# [' kenmare']
# [' cork']
# [' edgeworthstown']
# [' collon']
# [' dublin 12']
# [' balllincollig']
# [' dublin 13']
# [' dublin']
# [' dublin 9']
# [' grand canal street']
# [' tallaght dublin 24']
# [' kerry']
# [' dublin 3']
# [' waterford']
# [' tullamore']
# [' dublin']
# [' co. donegal']
# [' kildare']
# [' banogue']
# [' leighlinbridge']
# [' cork']
# [' adare']
# [' tralee']
# [' dublin']
# [' galway']
# [' monaghan']
# [' co meath']
# [' dublin 12']
# [' dublin 10']
# [' dundalk']
# [' tralee']
# [' tallaght']
# [' westmeath']
# [' sligo']
# [' donegal town']
# [' arklow']
# [' kerry']
# [' carrigaline']
# [' meath']
# [' waterford']
# [' kerry']
# [' dun laoghaire']
# [' westport']
# [' wexford']
# [' co kerry']
# [' monaghan']
# [' deansgrange']
# [' rathfarnham']
# [' delgany']
# [' bray rd']
# [' oulart  gorey']
# [' navan']
# [' dock rd']
# [' co roscommon']
# [' galway']
# [' galway']
# [' kildare']
# [' rathfarnham']
# [' dundrum']
# [' limerick']
# [' cork']
# [' midleton']
# [' wicklow']
# [' dublin']
# [' co kildare']
# [' tullamore']
# [' boyne rd']
# [' kerry']
# [' dublin 12']
# [' gorey']
# [' gort']
# [' co kildare']
# [' thurles']
# [' kenmare']
# [' mount merrion']
# [' lucan']
# [' waterford']
# [' annagry']
# [' smithboro']
# [' dublin 6']
# [' dublin 22']
# [' dublin 18']
# [' rochestown']
# [' dublin 3']
# [' upper glenageary road']
# [' offaly']
# [' balrothery']
# [' belclare tuam']
# [' cork']
# [' rush']
# [' templemore']
# [' tipperary']
# [' co. cork']
# [' offaly']
# [' portroe']
# [' celbridge']
# [' walkinstown']
# [' dublin 3']
# [' drogheda']
# [' blackrock']
# [' dublin 3']
# [' ballyshannon']
# [' co tipperary']
# [' co tipperary']
# [' dublin 9']
# [' athy']
# [' dublin 13']
# [' dublin 3']
# [' stepaside village dublin 18']
# [' dublin 1']
# [' nangor road']
# [' hyde st']
# [' dublin 22']
# [' kilkenny']
# [' charlotte quay']
# [' sandyford']
# [' corbally']
# [' cavan']
# [' kildare']
# [' stocking avenue  rathfarnham']
# [' co laois']
# [' wicklow']
# [' drumcondra']
# [' dundalk']
# [' mayo']
# [' celbridge']
# [' dublin 14']
# [' malahide']
# [' co galway']
# [' co tipperary']
# [' co laois']
# [' stillorgan']
# [' ballycullen']
# [' cork']
# [' malahide']
# [' nobber']
# [' mayo']
# [' dublin 8']
# [' wicklow']
# [' dublin']
# [' carrigaline']
# [' co. mayo']
# [' limerick']
# [' newbliss']
# [' dublin']
# [' kingscourt road']
# [' naas']
# [' sussex rd dublin 4']
# [' bohermore']
# [' castleknock']
# [' naas']
# [' dublin 15']
# [' killarney']
# [' tuam']
# [' carlow']
# [' meath']
# [' westmeath']
# [" bishop o'donnell road"]
# [' dublin 14']
# [' ballybunion']
# [' dublin 6w']
# [' ballina']
# [' dublin 6']
# [' loughrea']
# [' cavan']
# [' newtownmountkennedy']
# [' galway']
# [' carlow']
# [' dublin 14']
# [' palmerstown']
# [' drumcondra']
# [' letterkenny']
# [' cootehill']
# [' rathfarnham']
# [' clare']
# [' wicklow']
# [' mallow']
# [' dublin']
# [' waterford']
# [' tallaght']
# [' dublin 9']
# [' castleisland']
# [' meelick']
# [' donegal']
# [' dublin 6w']
# [' ballyfermot']
# [' donegal']
# [' laois']
# [' galway']
# [' co louth']
# [' galway']
# [' carney']
# [' hollystown']
# [' gorey']
# [' dunmanway']
# [' merrion road']
# [' kilkenny']
# [' athboy']
# [' dublin']
# [' portlaoise']
# [' swords']
# [' tully road']
# [' dublin 22']
# [' bantry']
# [' dingle']
# [' roscrea']
# [' dublin 17']
# [' dublin']
# [' co. cork']
# [' dublin']
# [' dunmanway']
# [' ballyhaunis']
# [' cork']
# [' enniskerry']
# [' enniscorthy']
# [' clare']
# [' bayside square west']
# [' roscommon']
# [' cootehill']
# [' upper glenageary road']
# [' dublin 12']
# [' dundalk']
# [' nenagh']
# [' cork']
# [' tralee']
# [' dublin 1']
# [' waterford']
# [' delgany']
# [' dublin 4']
# [' carrickmines']
# [' dublin 15']
# [' ballisodare']
# [' sligo']
# [' south lotts road']
# [' dungarvan']
# [' terenure']
# [' kilcock']
# [' laragh']
# [' kilbarry']
# [' mayo']
# [' co cavan']
# [' millstreet']
# [' cork']
# [' the moorings']
# [' limerick']
# [' dublin 5']
# [' galway']
# [' tullow road']
# [' meath']
# [' trim']
# [' mallow']
# [' enniscorthy']
# [' clonsilla']
# [' saggart']
# [' cobh']
# [' dublin']
# [' louth']
# [' dublin 7']
# [' naas']
# [' donegal']
# [' wicklow town']
# [' mullagh']
# [' bailey']
# [' meath']
# [' dublin 6']
# [' ballygrennan']
# [' glasnevin']
# [' dublin 11']
# [' dublin 16']
# [' co donegal']
# [' louth']
# [' irishtown']
# [' upper glenageary road']
# [' cobh']
# [' merrion rd dublin 4']
# [' killiney']
# [' doughiska']
# [' kiltipper road']
# [' dublin 7']
# [' clongriffin dublin 13']
# [' nenagh']
# [' kildare']
# [' new ross']
# [' beaumont dublin 9']
# [' mullingar']
# [' ferrybank']
# [' cabinteely']
# [' killenard']
# [' westport']
# [' westport']
# [' cavan']
# [' carlow']
# [' newport']
# [' cloneygowan']
# [' killarney']
# [' mayo']
# [' letterkenny']
# [' limerick']
# [' letterkenny']
# [' castlecomer rd']
# [' co laois']
# [' rochestown']
# [' wicklow town']
# [' waterford']
# [' newbridge']
# [' rush']
# [' co kerry']
# [' co cork']
# [' carlow']
# [' clay farm']
# [' churchtown']
# [' co cork']
# [' virginia']
# [' maynooth']
# [' galway']
# [' dublin 16']
# [' ballinaneashagh']
# [' artane']
# [' ennis']
# [' carrick on shannon']
# [' donegal']
# [' clare']
# [' dublin']
# [' templeogue']
# [' westmeath']
# [' dublin']
# [' dublin 14']
# [' letterkenny']
# [' clarecastle']
# [' tullaghan']
# [' foxrock']
# [' dublin 22']
# [' wexford']
# [' burt']
# [' kilmessan']
# [' dublin 6']
# [' kilbrittain']
# [' trim']
# [' co clare']
# [' whitehall']
# [' kildare']
# [' kilkenny']
# [' kenmare']
# [' athy']
# [' kerry']
# [' county kildare']
# [' raheen']
# [' bray rd']
# [' clondalkin']
# [' athboy']
# [' clare']
# [' killarney']
# [' macroom']
# [' cuffesgrange']
# [' strandhill']
# [' blackrock']
# [' bundoran']
# [' meath']
# [' cork']
# [' co cavan']
# [' butterfield ave']
# [' castlefin']
# [' ballymacoda']
# [' ashbourne']
# [' waterford']
# [' moycullen']
# [' sligo']
# [' ballinasloe']
# [' dublin']
# [' co dublin']
# [' maynooth']
# [' ashford']
# [' swords']
# [' limerick']
# [' athlone']
# [' offaly']
# [' gorey']
# [' dublin 18']
# [' castleknock dublin 15']
# [' carlow']
# [' wilton cork']
# [' westport']
# [' maxwell road']
# [' bray']
# [' co kildare']
# [' dublin 5']
# [' dublin 12']
# [' monkstown']
# [' pouladuff road']
# [' swords']
# [' offaly']
# [' station road']
# [' co cork']
# [' dublin']
# [' county monaghan']
# [' clonmel']
# [' dooradoyle road']
# [' golden']
# [' cork']
# [' charleville']
# [' dublin']
# [' lehenaghbeg']
# [' tralee']
# [' dublin 12']
# [' co. cork']
# [' kildare']
# [' dublin 24']
# [' wexford']
# [' farnham']
# [' limerick']
# [' cork']
# [' dublin 9']
# [' dublin']
# [' ballyvolane']
# [' dundalk']
# [' boyle']
# [' sligo']
# [' blackrock']
# [' dublin 6w']
# [' dublin']
# [' listowel']
# [' ballyconnell']
# [' dublin']
# [' ballinagare']
# [' cork']
# [' station road']
# [' cork']
# [' ashbourne']
# [' tarmon barry']
# [' dublin']
# [' co. longford']
# [' co kildare']
# [' claremorris']
# [' dundalk']
# [' cork']
# [' limerick']
# [' carlow']
# [' cork']
# [' donegal']
# [' dublin 14']
# [' killiney']
# [' dublin 17']
# [' co donegal']
# [' dublin 15']
# [' waterford']
# [' killiney']
# [' navan']
# [' mullingar']
# [' castlecomer rd']
# [' finglas dublin 11']
# [' meath']
# [' sandyford dublin 18']
# [' galway']
# [' co. roscommon']
# [' dublin 15']
# [' castletroy']
# [' galway']
# [' castlerea']
# [' offaly']
# [' rathmullen road']
# [' citywest']
# [' castlebar']
# [' mayo']
# [' stepaside']
# [' kilcullen road']
# [' longford']
# [' co clare']
# [' co dublin']
# [' co limerick']
# [' newbridge']
# [' dublin road']
# [' cork']
# [' carrigaline']
# [' dublin 22']
# [' ballbriggan']
# [' kilmeena']
# [' carlow']
# [' courtown']
# [' cork']
# [' gorey']
# [' co louth']
# [' sligo']
# [' donegal']
# [' cork']
# [' adamstown']
# [' drumree road']
# [' cork']
# [' county limerick']
# [' kerry']
# [' glasnevin']
# [' galway']
# [' tipperary']
# [' dublin 11']
# [' straffan']
# [' cobh']
# [' carbury']
# [' dublin 12']
# [' sligo']
# [' kilkenny']
# [' roscommon']
# [' dublin 6w']
# [' piltown']
# [' dundalk']
# [' dublin']
# [' finglas']
# [' newcastle']
# [' moycullen']
# [' loughrea']
# [' ongar dublin 15']
# [' co limerick']
# [' leitrim']
# [' limerick']
# [' sandyford']
# [' upper glenageary road']
# [' dublin 3']
# [' navan']
# [' kerry']
# [' stradbally']
# [' swinford']
# [' navan']
# [' dublin 2']
# [' castleknock']
# [' donegal']
# [' kilcock']
# [' louth']
# [' church st']
# [' scotshouse']
# [' kilkenny']
# [' ballymun']
# [' dalkey']
# [' limerick']
# [' wexford']
# [' kildare']
# [' cork']
# [' dublin 1']
# [' palmerstown dublin 20']
# [' dublin']
# [' cork']
# [' galway']
# [' caherciveen']
# [' dublin']
# [' county dublin']
# [' galway']
# [' co. louth']
# [' dromore west']
# [' tallaght dublin 24']
# [' co galway']
# [' cork']
# [' belturbet']
# [' gorey']
# [' westport']
# [' mount merrion']
# [' castlemartyr']
# [' athlone']
# [' ballinteen ave']
# [' newbridge']
# [' dublin']
# [' kildare town']
# [' drummin village']
# [' co wexford']
# [' ballsbridge']
# [' louth']
# [' shankill']
# [' meath']
# [' carrigaline']
# [' dublin']
# [' naas']
# [' tralee']
# [' co offaly']
# [' mohill']
# [' navan']
# [' portmarnock']
# [' dublin 18']
# [' castleknock']
# [' dublin 5']
# [' nenagh']
# [' dublin 13']
# [' lacken road  waterford']
# [' tuam']
# [' derrinturn']
# [' new ross']
# [' dublin 15']
# [' limerick']
# [' dublin 12']
# [' co limerick']
# [' newcastle west']
# [' cork']
# [' dublin 8']
# [' roscommon']
# [' dublin 15']
# [' letterkenny']
# [' newtownforbes']
# [' dublin 9']
# [' dublin 12']
# [' dun laoghaire']
# [' dublin 7']
# [' dunmore east']
# [' dungarvan']
# [' tuam']
# [' clonee dublin 15']
# [' dublin 11']
# [' tipperary']
# [' dublin 13']
# [' cork']
# [' millstreet']
# [' carlingford']
# [' co clare']
# [' kilkenny']
# [' westmeath']
# [' carlow']
# [' terenure']
# [' dublin 5']
# [' donegal']
# [' listowel']
# [' mayo']
# [' mullingar']
# [' laois']
# [' kerry']
# [' co. kerry']
# [' roscommon']
# [' dublin 13']
# [' killarney']
# [' dunsany']
# [' rush']
# [' naas']
# [' clonsilla']
# [' portarlington']
# [' dublin']
# [' maynooth']
# [' tipperary']
# [' dublin 15']
# [' 7-9 north circular road']
# [' enniscorthy']
# [' monaghan']
# [' ballinagare']
# [' waterford']
# [' blanchardstown']
# [' courtmacsherry']
# [' dublin 24']
# [' castlebar']
# [' ballinamore']
# [' lismore lawn']
# [' kilmallock']
# [' kilkenny']

# %%
print(len(addresses_list))
# Out:
# 10000

# %%
# Print out geocoded addresses to check that geocoding is working before commiting to running on all values
modified_addresses = []
error_addresses = []
geolocator = Nominatim(user_agent = 'property_analysis')

for i in range(len(addresses_list)):
    # print(address[0] + "," + address[1])
    address_string = addresses_list[i][0]
    # print(address_string)
    try:
        location = geolocator.geocode(address_string + ", Ireland")
        modified_addresses.append(location.address)
    except Exception:
        print(f"Geolocator couldn't get the address for address at position {i}")
        modified_addresses.append("Error")
        error_addresses.append(address_string)
    time.sleep(1)
# Out:
# Geolocator couldn't get the address for address at position 48
# Geolocator couldn't get the address for address at position 77
# Geolocator couldn't get the address for address at position 139
# Geolocator couldn't get the address for address at position 188
# Geolocator couldn't get the address for address at position 460
# Geolocator couldn't get the address for address at position 521
# Geolocator couldn't get the address for address at position 700
# Geolocator couldn't get the address for address at position 724
# Geolocator couldn't get the address for address at position 754
# Geolocator couldn't get the address for address at position 770
# Geolocator couldn't get the address for address at position 781
# Geolocator couldn't get the address for address at position 890
# Geolocator couldn't get the address for address at position 937
# Geolocator couldn't get the address for address at position 963
# Geolocator couldn't get the address for address at position 1109
# Geolocator couldn't get the address for address at position 1125
# Geolocator couldn't get the address for address at position 1136
# Geolocator couldn't get the address for address at position 1346
# Geolocator couldn't get the address for address at position 1379
# Geolocator couldn't get the address for address at position 1435
# Geolocator couldn't get the address for address at position 1460
# Geolocator couldn't get the address for address at position 1483
# Geolocator couldn't get the address for address at position 1601
# Geolocator couldn't get the address for address at position 1763
# Geolocator couldn't get the address for address at position 1764
# Geolocator couldn't get the address for address at position 1813
# Geolocator couldn't get the address for address at position 1997
# Geolocator couldn't get the address for address at position 1999
# Geolocator couldn't get the address for address at position 2036
# Geolocator couldn't get the address for address at position 2079
# Geolocator couldn't get the address for address at position 2216
# Geolocator couldn't get the address for address at position 2275
# Geolocator couldn't get the address for address at position 2302
# Geolocator couldn't get the address for address at position 2305
# Geolocator couldn't get the address for address at position 2461
# Geolocator couldn't get the address for address at position 2489
# Geolocator couldn't get the address for address at position 2502
# Geolocator couldn't get the address for address at position 2503
# Geolocator couldn't get the address for address at position 2600
# Geolocator couldn't get the address for address at position 2728
# Geolocator couldn't get the address for address at position 2784
# Geolocator couldn't get the address for address at position 2863
# Geolocator couldn't get the address for address at position 3009
# Geolocator couldn't get the address for address at position 3159
# Geolocator couldn't get the address for address at position 3341
# Geolocator couldn't get the address for address at position 3353
# Geolocator couldn't get the address for address at position 3382
# Geolocator couldn't get the address for address at position 3406
# Geolocator couldn't get the address for address at position 3443
# Geolocator couldn't get the address for address at position 3455
# Geolocator couldn't get the address for address at position 3727
# Geolocator couldn't get the address for address at position 3733
# Geolocator couldn't get the address for address at position 3868
# Geolocator couldn't get the address for address at position 3897
# Geolocator couldn't get the address for address at position 3939
# Geolocator couldn't get the address for address at position 3951
# Geolocator couldn't get the address for address at position 4074
# Geolocator couldn't get the address for address at position 4109
# Geolocator couldn't get the address for address at position 4161
# Geolocator couldn't get the address for address at position 4177
# Geolocator couldn't get the address for address at position 4191
# Geolocator couldn't get the address for address at position 4244
# Geolocator couldn't get the address for address at position 4277
# Geolocator couldn't get the address for address at position 4631
# Geolocator couldn't get the address for address at position 4657
# Geolocator couldn't get the address for address at position 4718
# Geolocator couldn't get the address for address at position 4724
# Geolocator couldn't get the address for address at position 4752
# Geolocator couldn't get the address for address at position 4777
# Geolocator couldn't get the address for address at position 4802
# Geolocator couldn't get the address for address at position 4840
# Geolocator couldn't get the address for address at position 4889
# Geolocator couldn't get the address for address at position 4898
# Geolocator couldn't get the address for address at position 4934
# Geolocator couldn't get the address for address at position 5001
# Geolocator couldn't get the address for address at position 5024
# Geolocator couldn't get the address for address at position 5044
# Geolocator couldn't get the address for address at position 5178
# Geolocator couldn't get the address for address at position 5239
# Geolocator couldn't get the address for address at position 5240
# Geolocator couldn't get the address for address at position 5253
# Geolocator couldn't get the address for address at position 5275
# Geolocator couldn't get the address for address at position 5318
# Geolocator couldn't get the address for address at position 5342
# Geolocator couldn't get the address for address at position 5359
# Geolocator couldn't get the address for address at position 5480
# Geolocator couldn't get the address for address at position 5687
# Geolocator couldn't get the address for address at position 5691
# Geolocator couldn't get the address for address at position 5704
# Geolocator couldn't get the address for address at position 5715
# Geolocator couldn't get the address for address at position 5739
# Geolocator couldn't get the address for address at position 5760
# Geolocator couldn't get the address for address at position 5845
# Geolocator couldn't get the address for address at position 5933
# Geolocator couldn't get the address for address at position 6068
# Geolocator couldn't get the address for address at position 6130
# Geolocator couldn't get the address for address at position 6145
# Geolocator couldn't get the address for address at position 6217
# Geolocator couldn't get the address for address at position 6329
# Geolocator couldn't get the address for address at position 6350
# Geolocator couldn't get the address for address at position 6388
# Geolocator couldn't get the address for address at position 6400
# Geolocator couldn't get the address for address at position 6532
# Geolocator couldn't get the address for address at position 6534
# Geolocator couldn't get the address for address at position 6655
# Geolocator couldn't get the address for address at position 6766
# Geolocator couldn't get the address for address at position 6789
# Geolocator couldn't get the address for address at position 6812
# Geolocator couldn't get the address for address at position 6818
# Geolocator couldn't get the address for address at position 6962
# Geolocator couldn't get the address for address at position 7038
# Geolocator couldn't get the address for address at position 7044
# Geolocator couldn't get the address for address at position 7048
# Geolocator couldn't get the address for address at position 7143
# Geolocator couldn't get the address for address at position 7161
# Geolocator couldn't get the address for address at position 7172
# Geolocator couldn't get the address for address at position 7180
# Geolocator couldn't get the address for address at position 7219
# Geolocator couldn't get the address for address at position 7229
# Geolocator couldn't get the address for address at position 7236
# Geolocator couldn't get the address for address at position 7289
# Geolocator couldn't get the address for address at position 7313
# Geolocator couldn't get the address for address at position 7338
# Geolocator couldn't get the address for address at position 7339
# Geolocator couldn't get the address for address at position 7517
# Geolocator couldn't get the address for address at position 7567
# Geolocator couldn't get the address for address at position 7618
# Geolocator couldn't get the address for address at position 7622
# Geolocator couldn't get the address for address at position 7683
# Geolocator couldn't get the address for address at position 7774
# Geolocator couldn't get the address for address at position 7788
# Geolocator couldn't get the address for address at position 7867
# Geolocator couldn't get the address for address at position 7919
# Geolocator couldn't get the address for address at position 7979
# Geolocator couldn't get the address for address at position 8068
# Geolocator couldn't get the address for address at position 8149
# Geolocator couldn't get the address for address at position 8251
# Geolocator couldn't get the address for address at position 8264
# Geolocator couldn't get the address for address at position 8326
# Geolocator couldn't get the address for address at position 8334
# Geolocator couldn't get the address for address at position 8402
# Geolocator couldn't get the address for address at position 8433
# Geolocator couldn't get the address for address at position 8439
# Geolocator couldn't get the address for address at position 8456
# Geolocator couldn't get the address for address at position 8535
# Geolocator couldn't get the address for address at position 8544
# Geolocator couldn't get the address for address at position 8545
# Geolocator couldn't get the address for address at position 8568
# Geolocator couldn't get the address for address at position 8586
# Geolocator couldn't get the address for address at position 8729
# Geolocator couldn't get the address for address at position 8918
# Geolocator couldn't get the address for address at position 8975
# Geolocator couldn't get the address for address at position 9066
# Geolocator couldn't get the address for address at position 9080
# Geolocator couldn't get the address for address at position 9096
# Geolocator couldn't get the address for address at position 9221
# Geolocator couldn't get the address for address at position 9314
# Geolocator couldn't get the address for address at position 9361
# Geolocator couldn't get the address for address at position 9434
# Geolocator couldn't get the address for address at position 9672
# Geolocator couldn't get the address for address at position 9757
# Geolocator couldn't get the address for address at position 9784
# Geolocator couldn't get the address for address at position 9815
# Geolocator couldn't get the address for address at position 9830
# Geolocator couldn't get the address for address at position 9841
# Geolocator couldn't get the address for address at position 9910

# %%
len(error_addresses)
# Out:
# 166

# %% [markdown]
# The output of 166 demonstrates that the number of addresses that couldn't be geolocated was a very small portion of the sample. However, the addresses that were successfully geolocated still had very inconsistent outputs with varying levels of detail provided in the address, potentially limiting the effectiveness of using the addresses directly in any predictive modelling.

# %%
modified_addresses
# Out:
# ['Malahide, Fingal, County Dublin, Leinster, K36 HN84, Éire / Ireland',
#  'Parnell Street, Rotunda B ED, Dublin, Dublin 1, Leinster, D01 R243, Éire / Ireland',
#  'Ballinamore, Ballinamore Municipal District, County Leitrim, Connacht, Éire / Ireland',
#  'Murrough Avenue, Murrough, Cathair na Gaillimhe, County Galway, Connacht, Éire / Ireland',
#  'Newbridge, The Municipal District of Kildare — Newbridge, County Kildare, Leinster, W12 AD93, Éire / Ireland',
#  'Hansfield, Blanchardstown-Blakestown ED, Fingal, County Dublin, Leinster, Éire / Ireland',
#  'Moyvane, Listowel Municipal District, County Kerry, Munster, Éire / Ireland',
#  'Cork, County Cork, Munster, T12 T997, Éire / Ireland',
#  'Ballyhaunis, Claremorris-Swinford Municipal District, County Mayo, Connacht, F35 NF82, Éire / Ireland',
#  'Caherdavin, The Metropolitan District of Limerick City, Limerick, County Limerick, Munster, V94TN5P, Éire / Ireland',
#  'Cathair na Gaillimhe, County Galway, Connacht, Éire / Ireland',
#  'County Roscommon, Connacht, Éire / Ireland',
#  'County Roscommon, Connacht, Éire / Ireland',
#  'Leopardstown, Galloping Green South, Stillorgan-Leopardstown ED, Dún Laoghaire-Rathdown, County Dublin, Leinster, D18 P521, Éire / Ireland',
#  'Smithfield, Arran Quay C ED, Dublin, Dublin 7, Leinster, Éire / Ireland',
#  'Raheny, Clontarf East A ED, Dublin, County Dublin, Leinster, D05 FW31, Éire / Ireland',
#  'Midleton, The Municipal District of East Cork, County Cork, Munster, P25 Y389, Éire / Ireland',
#  'Cathair na Gaillimhe, County Galway, Connacht, Éire / Ireland',
#  'Dublin, Dublin 1, Leinster, Éire / Ireland',
#  'Ardara, Glenties Municipal District, County Donegal, F94CX52, Éire / Ireland',
#  'Raheny, Clontarf East A ED, Dublin, County Dublin, Leinster, D05 FW31, Éire / Ireland',
#  'County Mayo, Connacht, Éire / Ireland',
#  'Courtown, The Municipal District of Gorey — Kilmuckridge, County Wexford, Leinster, Y25 X8C3, Éire / Ireland',
#  'Upper William Street, Glentworth A, The Metropolitan District of Limerick City, Limerick, County Limerick, Munster, V94 P8DD, Éire / Ireland',
#  'Balbriggan, Fingal, County Dublin, Leinster, K32 TW27, Éire / Ireland',
#  'County Longford, Leinster, Éire / Ireland',
#  'County Wexford, Leinster, Éire / Ireland',
#  'Clonmel Road, Cashel Rural, The Municipal District of Cahir — Cashel, County Tipperary, Munster, E25 PK81, Éire / Ireland',
#  'County Wexford, Leinster, Éire / Ireland',
#  'Westport, Westport-Belmullet Municipal District, County Mayo, Connacht, F28 RD39, Éire / Ireland',
#  'Letterkenny, Letterkenny Municipal District, County Donegal, F92 PD92, Éire / Ireland',
#  'Cliffoney, Sligo Municipal Borough District, County Sligo, Connacht, Éire / Ireland',
#  'Swords, Fingal, County Dublin, Leinster, K67 X8Y2, Éire / Ireland',
#  'Maryborough Hill, Maryborough, Douglas, Cork, County Cork, Munster, T12 D5RC, Éire / Ireland',
#  'Portmarnock, Fingal, County Dublin, Leinster, D13 YV05, Éire / Ireland',
#  'Dublin 22, Leinster, Éire / Ireland',
#  'Westport, Westport-Belmullet Municipal District, County Mayo, Connacht, F28 RD39, Éire / Ireland',
#  'County Louth, Leinster, Éire / Ireland',
#  'Adamstown, The Municipal District of New Ross, County Wexford, Leinster, Y21 H972, Éire / Ireland',
#  'Newbridge, The Municipal District of Kildare — Newbridge, County Kildare, Leinster, W12 AD93, Éire / Ireland',
#  'Cork, County Cork, Munster, T12 T997, Éire / Ireland',
#  'County Kildare, Leinster, Éire / Ireland',
#  'County Wexford, Leinster, Éire / Ireland',
#  'Tulsk, Boyle Municipal District, County Roscommon, Connacht, Éire / Ireland',
#  'Ratoath, The Municipal District of Ratoath, County Meath, Leinster, A85 XK30, Éire / Ireland',
#  'Portlaoise, The Municipal District of Portlaoise, County Laois, Leinster, R32 DX07, Éire / Ireland',
#  'Cathair na Gaillimhe, County Galway, Connacht, Éire / Ireland',
#  'Dublin 6, Leinster, Éire / Ireland',
#  ...]

# %%
error_addresses
# Out:
# [' dunlaoire',
#  ' city west dublin',
#  ' beaumount woods',
#  ' the gallops leopardstown dublin 18',
#  ' castaheaney',
#  ' ballisodare town centre',
#  ' drumcondar',
#  ' main st ballycotton',
#  ' ashourne',
#  ' dualla road cashel',
#  ' crandonagh',
#  ' county tippeary',
#  ' dublin6',
#  ' knockenduff',
#  ' maree',
#  ' crosslanes',
#  ' bonniconlon',
#  ' martiemo gardens west',
#  ' churchbay rd',
#  ' and 44/45  southern road',
#  ' gretystones',
#  ' santry demense',
#  ' 35a  35b  40  41 shannon grove',
#  ' scallagheen',
#  ' maree road',
#  ' meellick',
#  ' ballycullen  dubin 24',
#  ' city west',
#  ' dromahaire',
#  ' garraneagh',
#  ' asbourne',
#  ' aikens village',
#  ' fourmilehouse',
#  ' ballinahowen',
#  ' dublin7',
#  ' lecamy',
#  ' woodford wheaton hall dublin road',
#  ' dublin16',
#  ' royal canal park  ratoath rd',
#  ' drynam hall kinsealy dublin',
#  ' thonlagee',
#  ' co longfors',
#  ' poppinjtree',
#  ' casleknock dublin 15',
#  ' rochfordbridge',
#  ' gslway',
#  ' dublin12',
#  ' lehenaghbeg',
#  ' bretonfield rd',
#  ' knock na carra',
#  ' rathmullen road',
#  ' castaheaney',
#  ' dublin1',
#  ' jockey',
#  ' knightsbridge avenue  trim',
#  ' city west',
#  ' castlemain',
#  ' ballytivan',
#  ' co wexfor',
#  ' lower dorset st dublin 1',
#  ' co meth',
#  ' st angelas',
#  ' dubln 7',
#  ' st. johns rd west  dublin 8',
#  ' clodalkin',
#  ' castletown geo',
#  ' eyrcourt',
#  ' 0ranmore',
#  ' newcastlewest',
#  ' lyreacrompane',
#  ' woodford meadows  ballyconnell',
#  ' whites cross',
#  ' castaheaney',
#  ' the elms mount merrion',
#  ' cahercloeen',
#  ' ushers island dublin 8',
#  ' nass',
#  " templar's hall",
#  ' linden grove ave',
#  ' rathrum',
#  ' inverinco galway',
#  ' drumree road',
#  ' seafield golf and country club',
#  ' newcastlewest',
#  ' millotwn dublin 6',
#  ' vermount  menlough  ballinasloe',
#  ' knockenrahan upper',
#  ' clonskea dublin 14',
#  ' the lakelands virginia',
#  ' cows lane  temple bar',
#  ' bengal terrace',
#  ' gory',
#  ' castleforde  ballyconnell',
#  ' cloneygowas',
#  ' gallops leopardston dublin 18',
#  ' therles',
#  ' dublin6',
#  ' cruise park',
#  ' dublin1',
#  ' graigcullen',
#  ' & 174 -180 harolds cross road',
#  ' bishops quay',
#  ' pemtrokestown',
#  ' drumrooske',
#  ' glounthanue',
#  ' bonavalley',
#  ' st margarets road',
#  ' nqf 25 n16',
#  ' co letrim',
#  ' finglan',
#  ' dublin4',
#  ' crosslanes',
#  ' rathagr',
#  ' park west pointe dublin 12',
#  ' castlemain st athlone',
#  ' carrickgorman baileborough',
#  ' broadmeadow vale',
#  ' hartys quay',
#  ' 77 sir john rogersons quay',
#  ' drumree road',
#  ' dunlaoghaire',
#  ' ashobourne',
#  ' cappqamore',
#  ' knockenrahan upper',
#  ' ballynadrishoge  blackwater',
#  ' doochary',
#  ' cuonty kilkenny',
#  ' upper omahoney ave',
#  ' village malahide rd dublin 1',
#  ' lachinch',
#  ' stephens lane dublin 2',
#  ' curkish lane',
#  ' dublin rd  longford town',
#  ' ballyglunin',
#  ' clanmagadden',
#  ' barrowhouse road',
#  ' quinns road shankill',
#  ' carrrigaline',
#  ' scramogue',
#  ' castleforde ballyconnell',
#  ' athone',
#  ' castleford ballyconnell',
#  ' st josephs rd mallow',
#  ' ballinsloe',
#  ' dubiln 3',
#  ' dublin8',
#  ' scramogue',
#  ' drumree road',
#  ' castlenock',
#  ' kettles lane kinsealy dublin',
#  ' scramogue',
#  ' drumahair',
#  ' balintglass',
#  ' ballyhaunas',
#  ' county kiildare',
#  ' ushers island dublin 8',
#  ' road  finglas  dn147704f',
#  ' balllincollig',
#  ' smithboro',
#  ' ballinaneashagh',
#  ' lehenaghbeg',
#  ' tarmon barry',
#  ' rathmullen road',
#  ' ballbriggan',
#  ' drumree road',
#  ' ballinteen ave']

# %%
rppr_df
# Out:
#            Date                                            Address  \
# 0    2016-01-03  80 THE WATER RILL, WATERSIDE SWORDS RD, MALAHI...
# 1    2013-03-15                         apt 40, 109 parnell street
# 2    2011-01-14                            Cornabrone, Ballinamore
# 3    2016-10-27         46 TI CHORMAIC, GLEANN NA RI, MURROUGH AVE
# 4    2014-08-22      29 Barrettstown Meadows, Roseberry, NEWBRIDGE
# ...         ...                                                ...
# 9995 2021-10-25            27 AN SRUTHAN, TURLOUGH ROAD, CASTLEBAR
# 9996 2021-12-16            1 AN CUAN, GOLF LINKS ROAD, BALLINAMORE
# 9997 2016-08-16             6 TYRONE MEWS, TYRONE RD, LISMORE LAWN
# 9998 2021-11-15                   BALLYSHONAKIN, EFFIN, KILMALLOCK
# 9999 2017-09-25                            APT 1, NEW RD, KILKENNY
#
#      Postal_Code     County     Price Not_Full_Market_Price VAT_Exclusive  \
# 0            NaN     Dublin  260000.0                    No            No
# 1       Dublin 1     Dublin   81000.0                    No            No
# 2            NaN    Leitrim  155000.0                    No            No
# 3            NaN     Galway   60000.0                    No            No
# 4            NaN    Kildare  277533.0                    No           Yes
# ...          ...        ...       ...                   ...           ...
# 9995         NaN       Mayo   72000.0                   Yes            No
# 9996         NaN    Leitrim  112000.0                    No            No
# 9997         NaN  Waterford   60000.0                    No            No
# 9998         NaN   Limerick   80000.0                    No            No
# 9999         NaN   Kilkenny   80000.0                   Yes           Yes
#
#                     Description_of_Property  \
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 3     Second-Hand Dwelling house /Apartment
# 4             New Dwelling house /Apartment
# ...                                     ...
# 9995  Second-Hand Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9997  Second-Hand Dwelling house /Apartment
# 9998  Second-Hand Dwelling house /Apartment
# 9999          New Dwelling house /Apartment
#
#                               Property_Size_Description
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                            greater than 125 sq metres
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999  greater than or equal to 38 sq metres and less...
#
# [10000 rows x 9 columns]

# %%
# Nested loop used to add error addresses back into address list in their original format to remove
# 'Error' entries

i = 0
j = 0

while i < len(modified_addresses) and j < len(error_addresses):
    if modified_addresses[i] == "Error":
        modified_addresses[i] = error_addresses[j]
        j+=1
    i+=1

# %%
modified_addresses[48]
# Out:
# ' dunlaoire'

# %%
rppr_df['Address'] = modified_addresses
rppr_df
# Out:
#            Date                                            Address  \
# 0    2016-01-03  Malahide, Fingal, County Dublin, Leinster, K36...
# 1    2013-03-15  Parnell Street, Rotunda B ED, Dublin, Dublin 1...
# 2    2011-01-14  Ballinamore, Ballinamore Municipal District, C...
# 3    2016-10-27  Murrough Avenue, Murrough, Cathair na Gaillimh...
# 4    2014-08-22  Newbridge, The Municipal District of Kildare —...
# ...         ...                                                ...
# 9995 2021-10-25  Castlebar, Castlebar Municipal District, Count...
# 9996 2021-12-16  Ballinamore, Ballinamore Municipal District, C...
# 9997 2016-08-16  Finisterre Lawn, Landsend, Abbeyside, Dungarva...
# 9998 2021-11-15  Kilmallock, The Municipal District of Cappamor...
# 9999 2017-09-25          County Kilkenny, Leinster, Éire / Ireland
#
#      Postal_Code     County     Price Not_Full_Market_Price VAT_Exclusive  \
# 0            NaN     Dublin  260000.0                    No            No
# 1       Dublin 1     Dublin   81000.0                    No            No
# 2            NaN    Leitrim  155000.0                    No            No
# 3            NaN     Galway   60000.0                    No            No
# 4            NaN    Kildare  277533.0                    No           Yes
# ...          ...        ...       ...                   ...           ...
# 9995         NaN       Mayo   72000.0                   Yes            No
# 9996         NaN    Leitrim  112000.0                    No            No
# 9997         NaN  Waterford   60000.0                    No            No
# 9998         NaN   Limerick   80000.0                    No            No
# 9999         NaN   Kilkenny   80000.0                   Yes           Yes
#
#                     Description_of_Property  \
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 3     Second-Hand Dwelling house /Apartment
# 4             New Dwelling house /Apartment
# ...                                     ...
# 9995  Second-Hand Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9997  Second-Hand Dwelling house /Apartment
# 9998  Second-Hand Dwelling house /Apartment
# 9999          New Dwelling house /Apartment
#
#                               Property_Size_Description
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                            greater than 125 sq metres
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999  greater than or equal to 38 sq metres and less...
#
# [10000 rows x 9 columns]

# %% [markdown]
# ## Modifiying Post Codes, Date, VAT and Size Description

# %%
rppr_df['Postal_Code']
# Out:
# 0            NaN
# 1       Dublin 1
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 9995         NaN
# 9996         NaN
# 9997         NaN
# 9998         NaN
# 9999         NaN
# Name: Postal_Code, Length: 10000, dtype: category
# Categories (22, object): ['Dublin 1', 'Dublin 10', 'Dublin 11', 'Dublin 12', ..., 'Dublin 6w', 'Dublin 7', 'Dublin 8', 'Dublin 9']

# %%
type(rppr_df['Postal_Code'][0])
# Out:
# float

# %%
postal_code_bool = pd.isnull(rppr_df['Postal_Code'])
postal_code_df = pd.DataFrame(rppr_df[postal_code_bool])
postal_code_df
# Out:
#            Date                                            Address  \
# 0    2016-01-03  Malahide, Fingal, County Dublin, Leinster, K36...
# 2    2011-01-14  Ballinamore, Ballinamore Municipal District, C...
# 3    2016-10-27  Murrough Avenue, Murrough, Cathair na Gaillimh...
# 4    2014-08-22  Newbridge, The Municipal District of Kildare —...
# 6    2013-12-20  Moyvane, Listowel Municipal District, County K...
# ...         ...                                                ...
# 9995 2021-10-25  Castlebar, Castlebar Municipal District, Count...
# 9996 2021-12-16  Ballinamore, Ballinamore Municipal District, C...
# 9997 2016-08-16  Finisterre Lawn, Landsend, Abbeyside, Dungarva...
# 9998 2021-11-15  Kilmallock, The Municipal District of Cappamor...
# 9999 2017-09-25          County Kilkenny, Leinster, Éire / Ireland
#
#      Postal_Code     County     Price Not_Full_Market_Price VAT_Exclusive  \
# 0            NaN     Dublin  260000.0                    No            No
# 2            NaN    Leitrim  155000.0                    No            No
# 3            NaN     Galway   60000.0                    No            No
# 4            NaN    Kildare  277533.0                    No           Yes
# 6            NaN      Kerry  120000.0                    No           Yes
# ...          ...        ...       ...                   ...           ...
# 9995         NaN       Mayo   72000.0                   Yes            No
# 9996         NaN    Leitrim  112000.0                    No            No
# 9997         NaN  Waterford   60000.0                    No            No
# 9998         NaN   Limerick   80000.0                    No            No
# 9999         NaN   Kilkenny   80000.0                   Yes           Yes
#
#                     Description_of_Property  \
# 0     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 3     Second-Hand Dwelling house /Apartment
# 4             New Dwelling house /Apartment
# 6             New Dwelling house /Apartment
# ...                                     ...
# 9995  Second-Hand Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9997  Second-Hand Dwelling house /Apartment
# 9998  Second-Hand Dwelling house /Apartment
# 9999          New Dwelling house /Apartment
#
#                               Property_Size_Description
# 0                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                            greater than 125 sq metres
# 6                            greater than 125 sq metres
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999  greater than or equal to 38 sq metres and less...
#
# [8086 rows x 9 columns]

# %%
rppr_df.drop('Property_Size_Description', axis=1, inplace=True)

# %%
# Extract year and month data from the date feature and insert into the dataframe

year = rppr_df['Date'].dt.year
month = rppr_df['Date'].dt.month
rppr_df.insert(loc=1, column='Year_of_Sale', value=year)
rppr_df.insert(loc=2, column='Month_of_Sale', value=month)

# Drop the date feature as no longer necessary with year and month features
rppr_df.drop('Date', axis=1, inplace=True)

# Update new features to be categorical data types
rppr_df['Year_of_Sale'] = rppr_df['Year_of_Sale'].astype('category')
rppr_df['Month_of_Sale'] = rppr_df['Month_of_Sale'].astype('category')

# %%
# Loop over the dataframe itself, adding VAT to each of the

for idx, row in rppr_df.iterrows():
    if row['VAT_Exclusive'] == 'Yes':
        rppr_df.at[idx, 'Price'] = row['Price'] * 1.135

# %%
rppr_df.drop('VAT_Exclusive', axis=1, inplace=True)

# %% [markdown]
# ### Extra feature for major train routes added to dataset

# %%
train_bools = []
train_bools_yes_counties = ['Dublin', 'Galway', 'Wexford', 'Mayo', 'Kerry', 'Sligo', 'Cork', 'Limerick', 'Waterford']

for county in rppr_df['County']:
    if county in train_bools_yes_counties:
        train_bools.append('Yes')
    else:
        train_bools.append('No')

# %%
rppr_df.insert(4, 'Major_Train_Route', train_bools)
rppr_df
# Out:
#      Year_of_Sale Month_of_Sale  \
# 0            2016             1
# 1            2013             3
# 2            2011             1
# 3            2016            10
# 4            2014             8
# ...           ...           ...
# 9995         2021            10
# 9996         2021            12
# 9997         2016             8
# 9998         2021            11
# 9999         2017             9
#
#                                                 Address Postal_Code  \
# 0     Malahide, Fingal, County Dublin, Leinster, K36...         NaN
# 1     Parnell Street, Rotunda B ED, Dublin, Dublin 1...    Dublin 1
# 2     Ballinamore, Ballinamore Municipal District, C...         NaN
# 3     Murrough Avenue, Murrough, Cathair na Gaillimh...         NaN
# 4     Newbridge, The Municipal District of Kildare —...         NaN
# ...                                                 ...         ...
# 9995  Castlebar, Castlebar Municipal District, Count...         NaN
# 9996  Ballinamore, Ballinamore Municipal District, C...         NaN
# 9997  Finisterre Lawn, Landsend, Abbeyside, Dungarva...         NaN
# 9998  Kilmallock, The Municipal District of Cappamor...         NaN
# 9999          County Kilkenny, Leinster, Éire / Ireland         NaN
#
#      Major_Train_Route     County       Price Not_Full_Market_Price  \
# 0                  Yes     Dublin  260000.000                    No
# 1                  Yes     Dublin   81000.000                    No
# 2                   No    Leitrim  155000.000                    No
# 3                  Yes     Galway   60000.000                    No
# 4                   No    Kildare  314999.955                    No
# ...                ...        ...         ...                   ...
# 9995               Yes       Mayo   72000.000                   Yes
# 9996                No    Leitrim  112000.000                    No
# 9997               Yes  Waterford   60000.000                    No
# 9998               Yes   Limerick   80000.000                    No
# 9999                No   Kilkenny   90800.000                   Yes
#
#                     Description_of_Property
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 3     Second-Hand Dwelling house /Apartment
# 4             New Dwelling house /Apartment
# ...                                     ...
# 9995  Second-Hand Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9997  Second-Hand Dwelling house /Apartment
# 9998  Second-Hand Dwelling house /Apartment
# 9999          New Dwelling house /Apartment
#
# [10000 rows x 9 columns]

# %%
# As an aside, pandas seemed to return an error on swapping in new potential values for categorical datatypes
# based on some of the inherent properties of categorical data. Seemingly, this albeit messy solution of creating
# a list of values independent of pandas or a dataframe and then adding values to this list by index worked for
# creating a sequence of values to append to the dataframe in place of the post code information but this was
# admittedly not the ideal solution most likely

postal_codes = []
for i in range(rppr_df.shape[0]):
    if isinstance(rppr_df['Postal_Code'][i], float):
        postal_codes.append(rppr_df['County'][i])
    else:
        postal_codes.append(rppr_df['Postal_Code'][i])
postal_codes
# Out:
# ['Dublin',
#  'Dublin 1',
#  'Leitrim',
#  'Galway',
#  'Kildare',
#  'Dublin 15',
#  'Kerry',
#  'Cork',
#  'Mayo',
#  'Limerick',
#  'Galway',
#  'Roscommon',
#  'Roscommon',
#  'Dublin 18',
#  'Dublin 7',
#  'Dublin 5',
#  'Cork',
#  'Galway',
#  'Dublin 12',
#  'Donegal',
#  'Galway',
#  'Dublin 17',
#  'Galway',
#  'Sligo',
#  'Kildare',
#  'Kerry',
#  'Dublin 22',
#  'Cork',
#  'Donegal',
#  'Dublin 11',
#  'Meath',
#  'Cork',
#  'Offaly',
#  'Kilkenny',
#  'Dublin 13',
#  'Wicklow',
#  'Dublin',
#  'Clare',
#  'Dublin',
#  'Dublin 15',
#  'Donegal',
#  'Dublin 3',
#  'Cork',
#  'Waterford',
#  'Donegal',
#  'Dublin 18',
#  'Louth',
#  'Meath',
#  'Dublin',
#  'Dublin',
#  'Dublin 11',
#  'Dublin 14',
#  'Dublin 4',
#  'Waterford',
#  'Dublin 6',
#  'Waterford',
#  'Cork',
#  'Kilkenny',
#  'Wicklow',
#  'Waterford',
#  'Dublin',
#  'Dublin 5',
#  'Tipperary',
#  'Louth',
#  'Limerick',
#  'Dublin 1',
#  'Dublin',
#  'Limerick',
#  'Wexford',
#  'Laois',
#  'Kildare',
#  'Cork',
#  'Roscommon',
#  'Cavan',
#  'Dublin 18',
#  'Cork',
#  'Cork',
#  'Dublin 15',
#  'Limerick',
#  'Dublin 3',
#  'Dublin',
#  'Kerry',
#  'Meath',
#  'Mayo',
#  'Waterford',
#  'Dublin 7',
#  'Kerry',
#  'Cork',
#  'Meath',
#  'Dublin 16',
#  'Limerick',
#  'Mayo',
#  'Dublin',
#  'Kerry',
#  'Dublin 18',
#  'Monaghan',
#  'Dublin',
#  'Mayo',
#  'Dublin',
#  'Wexford',
#  'Dublin',
#  'Dublin 6',
#  'Dublin 12',
#  'Cork',
#  'Wicklow',
#  'Dublin 12',
#  'Dublin',
#  'Dublin',
#  'Cork',
#  'Clare',
#  'Louth',
#  'Cork',
#  'Cork',
#  'Dublin 9',
#  'Louth',
#  'Galway',
#  'Westmeath',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Cork',
#  'Tipperary',
#  'Waterford',
#  'Cork',
#  'Clare',
#  'Wexford',
#  'Dublin 15',
#  'Meath',
#  'Cork',
#  'Cork',
#  'Galway',
#  'Kerry',
#  'Louth',
#  'Limerick',
#  'Westmeath',
#  'Leitrim',
#  'Limerick',
#  'Sligo',
#  'Westmeath',
#  'Dublin 9',
#  'Galway',
#  'Monaghan',
#  'Cork',
#  'Kilkenny',
#  'Dublin',
#  'Dublin 3',
#  'Kildare',
#  'Wexford',
#  'Cork',
#  'Waterford',
#  'Louth',
#  'Monaghan',
#  'Dublin',
#  'Dublin 15',
#  'Dublin',
#  'Louth',
#  'Dublin',
#  'Westmeath',
#  'Westmeath',
#  'Dublin',
#  'Limerick',
#  'Dublin 11',
#  'Waterford',
#  'Dublin 9',
#  'Carlow',
#  'Limerick',
#  'Roscommon',
#  'Leitrim',
#  'Limerick',
#  'Kildare',
#  'Wicklow',
#  'Laois',
#  'Tipperary',
#  'Wicklow',
#  'Dublin',
#  'Wicklow',
#  'Dublin 9',
#  'Wexford',
#  'Galway',
#  'Louth',
#  'Donegal',
#  'Dublin',
#  'Galway',
#  'Laois',
#  'Cork',
#  'Dublin',
#  'Dublin',
#  'Kildare',
#  'Dublin 18',
#  'Dublin 16',
#  'Kilkenny',
#  'Laois',
#  'Clare',
#  'Dublin 24',
#  'Leitrim',
#  'Waterford',
#  'Kilkenny',
#  'Dublin',
#  'Dublin 22',
#  'Longford',
#  'Louth',
#  'Dublin 4',
#  'Meath',
#  'Tipperary',
#  'Dublin',
#  'Cork',
#  'Limerick',
#  'Clare',
#  'Dublin',
#  'Kerry',
#  'Wexford',
#  'Limerick',
#  'Wexford',
#  'Leitrim',
#  'Kildare',
#  'Laois',
#  'Meath',
#  'Dublin',
#  'Wicklow',
#  'Limerick',
#  'Cork',
#  'Dublin',
#  'Offaly',
#  'Dublin 8',
#  'Dublin 24',
#  'Meath',
#  'Dublin',
#  'Wicklow',
#  'Wicklow',
#  'Dublin 8',
#  'Kerry',
#  'Tipperary',
#  'Mayo',
#  'Longford',
#  'Dublin',
#  'Offaly',
#  'Cork',
#  'Limerick',
#  'Cavan',
#  'Cork',
#  'Dublin',
#  'Dublin 3',
#  'Dublin 15',
#  'Longford',
#  'Donegal',
#  'Dublin 9',
#  'Galway',
#  'Dublin 24',
#  'Laois',
#  'Galway',
#  'Meath',
#  'Laois',
#  'Louth',
#  'Sligo',
#  'Wexford',
#  'Carlow',
#  'Wexford',
#  'Galway',
#  'Offaly',
#  'Dublin',
#  'Sligo',
#  'Roscommon',
#  'Dublin 8',
#  'Dublin',
#  'Donegal',
#  'Laois',
#  'Cork',
#  'Kildare',
#  'Meath',
#  'Cork',
#  'Mayo',
#  'Carlow',
#  'Dublin',
#  'Dublin',
#  'Kilkenny',
#  'Dublin 8',
#  'Dublin 5',
#  'Wicklow',
#  'Dublin 4',
#  'Kildare',
#  'Wicklow',
#  'Dublin 7',
#  'Offaly',
#  'Dublin',
#  'Waterford',
#  'Mayo',
#  'Cork',
#  'Laois',
#  'Waterford',
#  'Kerry',
#  'Wexford',
#  'Dublin 9',
#  'Dublin',
#  'Waterford',
#  'Cork',
#  'Meath',
#  'Cork',
#  'Louth',
#  'Cavan',
#  'Dublin 13',
#  'Westmeath',
#  'Meath',
#  'Sligo',
#  'Cork',
#  'Dublin',
#  'Dublin 5',
#  'Cork',
#  'Galway',
#  'Donegal',
#  'Tipperary',
#  'Sligo',
#  'Dublin 15',
#  'Kildare',
#  'Dublin',
#  'Dublin 18',
#  'Cork',
#  'Tipperary',
#  'Clare',
#  'Sligo',
#  'Westmeath',
#  'Galway',
#  'Dublin 8',
#  'Dublin 6',
#  'Waterford',
#  'Dublin 11',
#  'Waterford',
#  'Meath',
#  'Laois',
#  'Dublin',
#  'Galway',
#  'Limerick',
#  'Wexford',
#  'Kildare',
#  'Monaghan',
#  'Waterford',
#  'Cork',
#  'Dublin',
#  'Galway',
#  'Cork',
#  'Dublin 15',
#  'Dublin',
#  'Louth',
#  'Cork',
#  'Dublin',
#  'Wexford',
#  'Meath',
#  'Dublin',
#  'Cork',
#  'Dublin 18',
#  'Limerick',
#  'Waterford',
#  'Louth',
#  'Dublin',
#  'Dublin',
#  'Dublin 3',
#  'Clare',
#  'Cork',
#  'Dublin',
#  'Dublin',
#  'Galway',
#  'Dublin',
#  'Louth',
#  'Dublin',
#  'Kildare',
#  'Cork',
#  'Limerick',
#  'Dublin',
#  'Galway',
#  'Sligo',
#  'Dublin 14',
#  'Louth',
#  'Dublin',
#  'Limerick',
#  'Dublin',
#  'Dublin 15',
#  'Meath',
#  'Cork',
#  'Westmeath',
#  'Dublin 18',
#  'Cork',
#  'Dublin',
#  'Wicklow',
#  'Cork',
#  'Dublin 10',
#  'Dublin 14',
#  'Dublin',
#  'Dublin 14',
#  'Westmeath',
#  'Kildare',
#  'Kerry',
#  'Galway',
#  'Donegal',
#  'Kerry',
#  'Cork',
#  'Dublin 12',
#  'Dublin 7',
#  'Tipperary',
#  'Dublin',
#  'Dublin 15',
#  'Galway',
#  'Dublin 18',
#  'Wicklow',
#  'Wicklow',
#  'Limerick',
#  'Offaly',
#  'Longford',
#  'Carlow',
#  'Waterford',
#  'Laois',
#  'Wicklow',
#  'Cavan',
#  'Dublin',
#  'Donegal',
#  'Wicklow',
#  'Kerry',
#  'Westmeath',
#  'Kildare',
#  'Cork',
#  'Kildare',
#  'Waterford',
#  'Meath',
#  'Laois',
#  'Waterford',
#  'Dublin 12',
#  'Kerry',
#  'Limerick',
#  'Leitrim',
#  'Kildare',
#  'Dublin 15',
#  'Dublin',
#  'Galway',
#  'Dublin 15',
#  'Offaly',
#  'Dublin 16',
#  'Dublin 9',
#  'Kildare',
#  'Dublin 8',
#  'Louth',
#  'Dublin 18',
#  'Sligo',
#  'Kerry',
#  'Wexford',
#  'Dublin',
#  'Cork',
#  'Louth',
#  'Dublin 3',
#  'Dublin 24',
#  'Wexford',
#  'Dublin 6',
#  'Dublin 14',
#  'Dublin 3',
#  'Dublin',
#  'Kerry',
#  'Cork',
#  'Donegal',
#  'Donegal',
#  'Louth',
#  'Dublin',
#  'Wicklow',
#  'Dublin',
#  'Dublin 15',
#  'Dublin 3',
#  'Cork',
#  'Longford',
#  'Wicklow',
#  'Cork',
#  'Wexford',
#  'Dublin',
#  'Dublin',
#  'Sligo',
#  'Kerry',
#  'Cork',
#  'Sligo',
#  'Mayo',
#  'Westmeath',
#  'Dublin',
#  'Roscommon',
#  'Dublin',
#  'Cork',
#  'Dublin 24',
#  'Cork',
#  'Dublin 15',
#  'Mayo',
#  'Carlow',
#  'Cavan',
#  'Galway',
#  'Tipperary',
#  'Dublin 5',
#  'Leitrim',
#  'Wicklow',
#  'Dublin',
#  'Galway',
#  'Louth',
#  'Dublin 6',
#  'Meath',
#  'Cork',
#  'Leitrim',
#  'Louth',
#  'Kildare',
#  'Dublin',
#  'Cavan',
#  'Dublin',
#  'Cork',
#  'Sligo',
#  'Galway',
#  'Wexford',
#  'Dublin',
#  'Cork',
#  'Kildare',
#  'Louth',
#  'Longford',
#  'Meath',
#  'Dublin 15',
#  'Meath',
#  'Kerry',
#  'Kilkenny',
#  'Dublin 22',
#  'Donegal',
#  'Mayo',
#  'Roscommon',
#  'Dublin 22',
#  'Sligo',
#  'Dublin 14',
#  'Dublin 1',
#  'Wexford',
#  'Cork',
#  'Limerick',
#  'Kilkenny',
#  'Cork',
#  'Wicklow',
#  'Dublin',
#  'Dublin 13',
#  'Galway',
#  'Dublin 15',
#  'Cork',
#  'Waterford',
#  'Louth',
#  'Dublin 13',
#  'Cork',
#  'Cork',
#  'Dublin 4',
#  'Dublin 18',
#  'Carlow',
#  'Kildare',
#  'Kerry',
#  'Carlow',
#  'Kerry',
#  'Dublin 7',
#  'Meath',
#  'Cork',
#  'Kildare',
#  'Monaghan',
#  'Cork',
#  'Dublin',
#  'Meath',
#  'Tipperary',
#  'Dublin',
#  'Meath',
#  'Dublin',
#  'Donegal',
#  'Limerick',
#  'Wexford',
#  'Sligo',
#  'Dublin 16',
#  'Dublin 16',
#  'Kerry',
#  'Mayo',
#  'Tipperary',
#  'Leitrim',
#  'Dublin',
#  'Dublin 11',
#  'Cork',
#  'Dublin 18',
#  'Dublin 11',
#  'Cavan',
#  'Cork',
#  'Dublin 8',
#  'Wexford',
#  'Waterford',
#  'Donegal',
#  'Kildare',
#  'Cork',
#  'Limerick',
#  'Waterford',
#  'Cork',
#  'Dublin 5',
#  'Offaly',
#  'Tipperary',
#  'Galway',
#  'Limerick',
#  'Wexford',
#  'Dublin 8',
#  'Limerick',
#  'Waterford',
#  'Meath',
#  'Westmeath',
#  'Galway',
#  'Kilkenny',
#  'Galway',
#  'Dublin 15',
#  'Louth',
#  'Dublin 22',
#  'Cork',
#  'Dublin',
#  'Dublin 14',
#  'Dublin',
#  'Dublin',
#  'Kerry',
#  'Dublin 18',
#  'Dublin',
#  'Wicklow',
#  'Kerry',
#  'Dublin 15',
#  'Dublin',
#  'Cavan',
#  'Mayo',
#  'Cork',
#  'Dublin 18',
#  'Galway',
#  'Mayo',
#  'Kerry',
#  'Wicklow',
#  'Dublin',
#  'Dublin 22',
#  'Dublin',
#  'Kilkenny',
#  'Dublin 13',
#  'Meath',
#  'Dublin',
#  'Wexford',
#  'Donegal',
#  'Dublin',
#  'Dublin 8',
#  'Wexford',
#  'Dublin 9',
#  'Waterford',
#  'Laois',
#  'Dublin',
#  'Galway',
#  'Dublin 24',
#  'Dublin',
#  'Galway',
#  'Sligo',
#  'Meath',
#  'Louth',
#  'Dublin',
#  'Dublin',
#  'Cork',
#  'Dublin 12',
#  'Cork',
#  'Wicklow',
#  'Limerick',
#  'Kildare',
#  'Galway',
#  'Kilkenny',
#  'Meath',
#  'Dublin',
#  'Kildare',
#  'Dublin 18',
#  'Cork',
#  'Wicklow',
#  'Louth',
#  'Offaly',
#  'Dublin 11',
#  'Tipperary',
#  'Dublin 7',
#  'Dublin',
#  'Roscommon',
#  'Wexford',
#  'Dublin 3',
#  'Dublin',
#  'Dublin',
#  'Donegal',
#  'Cavan',
#  'Dublin',
#  'Leitrim',
#  'Galway',
#  'Dublin',
#  'Cork',
#  'Dublin 15',
#  'Donegal',
#  'Wicklow',
#  'Dublin',
#  'Dublin 4',
#  'Westmeath',
#  'Dublin 17',
#  'Mayo',
#  'Tipperary',
#  'Donegal',
#  'Kildare',
#  'Kilkenny',
#  'Donegal',
#  'Dublin 3',
#  'Cork',
#  'Kildare',
#  'Dublin',
#  'Cork',
#  'Dublin',
#  'Meath',
#  'Cork',
#  'Dublin',
#  'Cork',
#  'Galway',
#  'Dublin',
#  'Dublin 3',
#  'Dublin 24',
#  'Meath',
#  'Dublin 14',
#  'Laois',
#  'Dublin 7',
#  'Dublin 7',
#  'Dublin 3',
#  'Cork',
#  'Dublin',
#  'Waterford',
#  'Meath',
#  'Kildare',
#  'Cork',
#  'Kildare',
#  'Wexford',
#  'Louth',
#  'Galway',
#  'Leitrim',
#  'Louth',
#  'Cork',
#  'Cork',
#  'Dublin',
#  'Limerick',
#  'Kildare',
#  'Waterford',
#  'Roscommon',
#  'Wicklow',
#  'Meath',
#  'Tipperary',
#  'Wexford',
#  'Donegal',
#  'Dublin',
#  'Wicklow',
#  'Kerry',
#  'Laois',
#  'Meath',
#  'Dublin 7',
#  'Dublin',
#  'Roscommon',
#  'Dublin',
#  'Kilkenny',
#  'Dublin 7',
#  'Cavan',
#  'Cork',
#  'Kildare',
#  'Dublin',
#  'Dublin 12',
#  'Dublin',
#  'Galway',
#  'Meath',
#  'Waterford',
#  'Dublin',
#  'Kildare',
#  'Dublin 15',
#  'Mayo',
#  'Kerry',
#  'Galway',
#  'Roscommon',
#  'Mayo',
#  'Cork',
#  'Cork',
#  'Dublin 6',
#  'Dublin 18',
#  'Dublin',
#  'Laois',
#  'Tipperary',
#  'Meath',
#  'Dublin 11',
#  'Dublin 5',
#  'Roscommon',
#  'Dublin',
#  'Dublin',
#  'Dublin 6',
#  'Waterford',
#  'Dublin 24',
#  'Sligo',
#  'Donegal',
#  'Kerry',
#  'Dublin 15',
#  'Galway',
#  'Dublin',
#  'Cork',
#  'Dublin 18',
#  'Meath',
#  'Dublin 16',
#  'Dublin 13',
#  'Roscommon',
#  'Dublin',
#  'Cork',
#  'Louth',
#  'Longford',
#  'Dublin',
#  'Kildare',
#  'Dublin 24',
#  'Kildare',
#  'Limerick',
#  'Dublin',
#  'Galway',
#  'Cork',
#  'Cork',
#  'Galway',
#  'Cork',
#  'Kerry',
#  'Kilkenny',
#  'Limerick',
#  'Waterford',
#  'Dublin 22',
#  'Longford',
#  'Wicklow',
#  'Sligo',
#  'Tipperary',
#  'Dublin 8',
#  'Dublin 18',
#  'Roscommon',
#  'Limerick',
#  'Kildare',
#  'Dublin 24',
#  'Dublin 8',
#  'Wexford',
#  'Limerick',
#  'Limerick',
#  'Cavan',
#  'Clare',
#  'Dublin',
#  'Monaghan',
#  'Dublin 11',
#  'Kilkenny',
#  'Cavan',
#  'Cavan',
#  'Dublin 22',
#  'Galway',
#  'Dublin 24',
#  'Dublin 12',
#  'Dublin 13',
#  'Wicklow',
#  'Wexford',
#  'Limerick',
#  'Galway',
#  'Dublin 15',
#  'Kerry',
#  'Limerick',
#  'Kildare',
#  'Donegal',
#  'Meath',
#  'Dublin',
#  'Cavan',
#  'Cork',
#  'Dublin',
#  'Carlow',
#  'Dublin',
#  'Galway',
#  'Cork',
#  'Meath',
#  'Kerry',
#  'Donegal',
#  'Cork',
#  'Laois',
#  'Dublin 14',
#  'Dublin 18',
#  'Dublin',
#  'Offaly',
#  'Meath',
#  'Offaly',
#  'Laois',
#  'Meath',
#  'Galway',
#  'Donegal',
#  'Kildare',
#  'Dublin',
#  'Louth',
#  'Clare',
#  'Louth',
#  'Offaly',
#  'Dublin',
#  'Carlow',
#  'Carlow',
#  'Dublin',
#  'Offaly',
#  'Dublin 6',
#  'Dublin',
#  'Waterford',
#  'Westmeath',
#  'Sligo',
#  'Dublin 5',
#  'Dublin',
#  'Tipperary',
#  'Limerick',
#  'Donegal',
#  'Kerry',
#  'Limerick',
#  'Tipperary',
#  'Limerick',
#  'Kerry',
#  'Galway',
#  'Galway',
#  'Kildare',
#  'Westmeath',
#  'Louth',
#  'Dublin',
#  'Laois',
#  'Dublin',
#  'Mayo',
#  'Mayo',
#  'Meath',
#  'Limerick',
#  'Donegal',
#  'Cork',
#  'Clare',
#  'Dublin 6w',
#  'Kerry',
#  'Galway',
#  'Sligo',
#  'Kildare',
#  'Clare',
#  'Sligo',
#  'Waterford',
#  'Dublin 16',
#  'Dublin 4',
#  'Laois',
#  'Laois',
#  'Dublin 11',
#  'Donegal',
#  'Dublin 5',
#  'Dublin 24',
#  'Cork',
#  'Donegal',
#  'Dublin',
#  'Dublin 3',
#  'Cork',
#  'Cork',
#  'Wexford',
#  'Cork',
#  'Dublin 6',
#  'Dublin',
#  'Kerry',
#  'Galway',
#  'Dublin',
#  'Dublin 2',
#  'Wicklow',
#  'Dublin 2',
#  'Cork',
#  'Dublin 17',
#  'Dublin 15',
#  'Dublin 6',
#  'Dublin',
#  'Dublin 9',
#  'Wexford',
#  'Tipperary',
#  'Dublin',
#  'Dublin 10',
#  'Dublin 7',
#  'Meath',
#  'Dublin',
#  'Galway',
#  'Dublin',
#  'Kerry',
#  'Cork',
#  'Galway',
#  'Waterford',
#  'Dublin 3',
#  'Wexford',
#  'Donegal',
#  'Wicklow',
#  'Cork',
#  'Meath',
#  'Kerry',
#  'Roscommon',
#  'Dublin 5',
#  'Mayo',
#  'Wexford',
#  'Limerick',
#  'Dublin',
#  'Longford',
#  'Wexford',
#  'Tipperary',
#  'Wexford',
#  'Mayo',
#  'Donegal',
#  'Sligo',
#  'Dublin',
#  'Cork',
#  'Dublin 13',
#  'Dublin 22',
#  'Mayo',
#  'Louth',
#  'Dublin',
#  'Kildare',
#  'Cork',
#  'Kildare',
#  'Wexford',
#  'Roscommon',
#  'Meath',
#  'Laois',
#  'Galway',
#  'Dublin',
#  ...]

# %%
# Insert post code or county feature to replace the post code feature

rppr_df.insert(loc=1, column='Post_Code_or_County', value=postal_codes)
rppr_df.drop('Postal_Code', axis=1, inplace=True)
rppr_df
# Out:
#      Year_of_Sale Post_Code_or_County Month_of_Sale  \
# 0            2016              Dublin             1
# 1            2013            Dublin 1             3
# 2            2011             Leitrim             1
# 3            2016              Galway            10
# 4            2014             Kildare             8
# ...           ...                 ...           ...
# 9995         2021                Mayo            10
# 9996         2021             Leitrim            12
# 9997         2016           Waterford             8
# 9998         2021            Limerick            11
# 9999         2017            Kilkenny             9
#
#                                                 Address Major_Train_Route  \
# 0     Malahide, Fingal, County Dublin, Leinster, K36...               Yes
# 1     Parnell Street, Rotunda B ED, Dublin, Dublin 1...               Yes
# 2     Ballinamore, Ballinamore Municipal District, C...                No
# 3     Murrough Avenue, Murrough, Cathair na Gaillimh...               Yes
# 4     Newbridge, The Municipal District of Kildare —...                No
# ...                                                 ...               ...
# 9995  Castlebar, Castlebar Municipal District, Count...               Yes
# 9996  Ballinamore, Ballinamore Municipal District, C...                No
# 9997  Finisterre Lawn, Landsend, Abbeyside, Dungarva...               Yes
# 9998  Kilmallock, The Municipal District of Cappamor...               Yes
# 9999          County Kilkenny, Leinster, Éire / Ireland                No
#
#          County       Price Not_Full_Market_Price  \
# 0        Dublin  260000.000                    No
# 1        Dublin   81000.000                    No
# 2       Leitrim  155000.000                    No
# 3        Galway   60000.000                    No
# 4       Kildare  314999.955                    No
# ...         ...         ...                   ...
# 9995       Mayo   72000.000                   Yes
# 9996    Leitrim  112000.000                    No
# 9997  Waterford   60000.000                    No
# 9998   Limerick   80000.000                    No
# 9999   Kilkenny   90800.000                   Yes
#
#                     Description_of_Property
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 3     Second-Hand Dwelling house /Apartment
# 4             New Dwelling house /Apartment
# ...                                     ...
# 9995  Second-Hand Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9997  Second-Hand Dwelling house /Apartment
# 9998  Second-Hand Dwelling house /Apartment
# 9999          New Dwelling house /Apartment
#
# [10000 rows x 9 columns]

# %% [markdown]
# ### Save dataframe to csv to prevent geolocating again

# %%
rppr_df.to_csv('ppr-14332591-cleaning1')

# %% [markdown]
# ## Assess clamping outcome for dataset

# %%
rppr_df2 = pd.read_csv('ppr-14332591-cleaning1.csv', keep_default_na = True, delimiter=',', skipinitialspace = True)

# %%
rppr_df2
# Out:
#       Unnamed: 0  Year_of_Sale Post_Code_or_County  Month_of_Sale  \
# 0              0          2016              Dublin              1
# 1              1          2013            Dublin 1              3
# 2              2          2011             Leitrim              1
# 3              3          2016              Galway             10
# 4              4          2014             Kildare              8
# ...          ...           ...                 ...            ...
# 9995        9995          2021                Mayo             10
# 9996        9996          2021             Leitrim             12
# 9997        9997          2016           Waterford              8
# 9998        9998          2021            Limerick             11
# 9999        9999          2017            Kilkenny              9
#
#                                                 Address Major_Train_Route  \
# 0     Malahide, Fingal, County Dublin, Leinster, K36...               Yes
# 1     Parnell Street, Rotunda B ED, Dublin, Dublin 1...               Yes
# 2     Ballinamore, Ballinamore Municipal District, C...                No
# 3     Murrough Avenue, Murrough, Cathair na Gaillimh...               Yes
# 4     Newbridge, The Municipal District of Kildare —...                No
# ...                                                 ...               ...
# 9995  Castlebar, Castlebar Municipal District, Count...               Yes
# 9996  Ballinamore, Ballinamore Municipal District, C...                No
# 9997  Finisterre Lawn, Landsend, Abbeyside, Dungarva...               Yes
# 9998  Kilmallock, The Municipal District of Cappamor...               Yes
# 9999          County Kilkenny, Leinster, Éire / Ireland                No
#
#          County       Price Not_Full_Market_Price  \
# 0        Dublin  260000.000                    No
# 1        Dublin   81000.000                    No
# 2       Leitrim  155000.000                    No
# 3        Galway   60000.000                    No
# 4       Kildare  314999.955                    No
# ...         ...         ...                   ...
# 9995       Mayo   72000.000                   Yes
# 9996    Leitrim  112000.000                    No
# 9997  Waterford   60000.000                    No
# 9998   Limerick   80000.000                    No
# 9999   Kilkenny   90800.000                   Yes
#
#                     Description_of_Property
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 3     Second-Hand Dwelling house /Apartment
# 4             New Dwelling house /Apartment
# ...                                     ...
# 9995  Second-Hand Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9997  Second-Hand Dwelling house /Apartment
# 9998  Second-Hand Dwelling house /Apartment
# 9999          New Dwelling house /Apartment
#
# [10000 rows x 10 columns]

# %%
rppr_df2.drop(rppr_df2.columns[[0]], axis=1, inplace=True)
rppr_df2
# Out:
#       Year_of_Sale Post_Code_or_County  Month_of_Sale  \
# 0             2016              Dublin              1
# 1             2013            Dublin 1              3
# 2             2011             Leitrim              1
# 3             2016              Galway             10
# 4             2014             Kildare              8
# ...            ...                 ...            ...
# 9995          2021                Mayo             10
# 9996          2021             Leitrim             12
# 9997          2016           Waterford              8
# 9998          2021            Limerick             11
# 9999          2017            Kilkenny              9
#
#                                                 Address Major_Train_Route  \
# 0     Malahide, Fingal, County Dublin, Leinster, K36...               Yes
# 1     Parnell Street, Rotunda B ED, Dublin, Dublin 1...               Yes
# 2     Ballinamore, Ballinamore Municipal District, C...                No
# 3     Murrough Avenue, Murrough, Cathair na Gaillimh...               Yes
# 4     Newbridge, The Municipal District of Kildare —...                No
# ...                                                 ...               ...
# 9995  Castlebar, Castlebar Municipal District, Count...               Yes
# 9996  Ballinamore, Ballinamore Municipal District, C...                No
# 9997  Finisterre Lawn, Landsend, Abbeyside, Dungarva...               Yes
# 9998  Kilmallock, The Municipal District of Cappamor...               Yes
# 9999          County Kilkenny, Leinster, Éire / Ireland                No
#
#          County       Price Not_Full_Market_Price  \
# 0        Dublin  260000.000                    No
# 1        Dublin   81000.000                    No
# 2       Leitrim  155000.000                    No
# 3        Galway   60000.000                    No
# 4       Kildare  314999.955                    No
# ...         ...         ...                   ...
# 9995       Mayo   72000.000                   Yes
# 9996    Leitrim  112000.000                    No
# 9997  Waterford   60000.000                    No
# 9998   Limerick   80000.000                    No
# 9999   Kilkenny   90800.000                   Yes
#
#                     Description_of_Property
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 3     Second-Hand Dwelling house /Apartment
# 4             New Dwelling house /Apartment
# ...                                     ...
# 9995  Second-Hand Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9997  Second-Hand Dwelling house /Apartment
# 9998  Second-Hand Dwelling house /Apartment
# 9999          New Dwelling house /Apartment
#
# [10000 rows x 9 columns]

# %%
rppr_df2.describe().T
# Out:
#                  count           mean            std     min       25%  \
# Year_of_Sale   10000.0    2016.551500       3.136962  2010.0    2014.0
# Month_of_Sale  10000.0       6.882200       3.507271     1.0       4.0
# Price          10000.0  259725.890737  336004.422183  5280.0  120000.0
#
#                     50%       75%           max
# Year_of_Sale     2017.0    2019.0  2.022000e+03
# Month_of_Sale       7.0      10.0  1.200000e+01
# Price          205000.0  320000.0  1.851000e+07

# %%
prices = rppr_df2['Price']

# %%
# Check how many prices would be affected by clamping

price_count = 0
for price in prices:
    if price > (320000 + (1.5 * 200000)):
        print(price)
        price_count += 1
print(price_count)
# Out:
# 656149.0
# 649999.745
# 1300000.0
# 3500000.0
# 851251.135
# 890000.0
# 645000.0
# 760000.0
# 625000.0
# 635000.0
# 625000.0
# 950000.0
# 1386652.2
# 685000.0
# 2500000.0
# 1315000.0
# 905000.0
# 685124.59
# 865000.0
# 650000.0
# 930700.0
# 620000.56
# 705000.0
# 825000.0
# 750000.0
# 1225000.0
# 640000.0
# 800000.0
# 680000.0
# 925000.03
# 1100000.0
# 18510000.006750003
# 750000.0
# 645000.0
# 687500.0
# 810000.0
# 1900000.0
# 890000.0
# 870000.0
# 704999.99495
# 740000.0
# 864999.39
# 629998.775
# 675000.0
# 754000.0
# 745000.0
# 635000.0
# 900000.0
# 765000.0
# 729237.5
# 640000.395
# 1395000.0
# 1675000.0
# 710000.0
# 875000.0
# 975000.0
# 855000.0
# 700000.0
# 675900.0
# 785000.0
# 627349.96875
# 1039999.98925
# 645000.0
# 2000000.0
# 1238196.79915
# 792500.0
# 760000.0
# 645000.0
# 710000.0
# 3025000.0
# 685000.0
# 924998.895
# 682000.0
# 822000.0
# 930000.0
# 776000.0
# 735000.0
# 650000.0
# 634999.9936
# 1418750.0
# 1100000.0
# 745000.0
# 700000.0
# 750000.0
# 660000.0
# 815000.0
# 1100000.0
# 735000.0
# 909999.87
# 660000.0
# 1200000.0
# 638000.0
# 759999.9952
# 870000.0
# 1260000.0
# 840000.0
# 765000.0
# 625000.0
# 1300000.0
# 630000.0
# 1100000.0
# 727500.0
# 774999.9963
# 630000.0007999999
# 1549999.9926
# 855000.0
# 1070000.0
# 656000.0
# 825000.0
# 1152025.0
# 755000.0
# 1020000.0
# 650000.0
# 649999.9946999999
# 849999.23
# 970000.0
# 5649462.5
# 1250000.0
# 819999.9996
# 4000000.0
# 639999.99775
# 1029998.88
# 700000.0
# 815000.0
# 909999.87
# 910000.0062
# 685000.0
# 740000.0
# 775000.0
# 1750000.0
# 650000.0
# 665000.0
# 837004.0
# 1404999.475
# 1500000.0
# 1000000.0
# 1900000.0
# 680000.0
# 1120000.0
# 1225939.605
# 1100000.0
# 625000.0
# 700000.0
# 870000.0
# 650000.0
# 733210.0
# 655000.0
# 750000.0
# 8500000.0
# 879625.0
# 1117500.0
# 850000.0
# 642000.0
# 800000.0
# 1599999.966
# 1270000.0
# 960000.0
# 1640000.0
# 640000.0
# 855000.0
# 680000.0
# 1431111.0
# 665000.0
# 770000.0
# 1080000.0
# 2614693.825
# 2500000.0
# 894999.71
# 800000.0
# 675000.39
# 825000.0
# 1000000.0
# 865000.0
# 1150000.0
# 1475000.0
# 820000.0
# 975000.0
# 674699.9555
# 727731.0
# 880000.0
# 633000.0
# 704999.575
# 694999.998
# 700000.0
# 634999.9936
# 804500.0
# 695000.0
# 1080000.0
# 720000.0
# 730000.0
# 770000.0
# 800000.0
# 700000.0
# 1035000.0
# 648764.865
# 1475000.0
# 970000.0
# 639000.0
# 1800000.0
# 1190000.0
# 684999.74
# 1050888.0
# 1400000.0
# 650000.0
# 730000.0
# 651000.0
# 625000.0
# 1360000.0
# 1500000.0
# 704999.575
# 800000.0
# 825000.0
# 1050000.0
# 700000.0
# 810000.0
# 1000000.0
# 1550000.00395
# 900000.0
# 1023000.0
# 634999.585
# 659999.9916500001
# 1250000.0
# 775000.0
# 710000.0
# 1700000.0
# 994998.885
# 645000.0
# 635000.0
# 705000.0
# 1500000.0
# 1125000.0
# 9700000.0
# 1408000.0
# 1300000.0
# 810000.0
# 1100000.005
# 658300.0
# 685000.0
# 690000.0
# 835000.0
# 718000.0
# 920115.19
# 695000.0
# 2181000.0
# 654999.9875
# 900000.0
# 740000.0
# 735000.0
# 650000.0
# 695000.0
# 675000.0
# 1290000.0
# 1180000.0
# 1700000.0
# 696000.0
# 969999.97655
# 2100000.0
# 884999.225
# 635000.0
# 860000.0
# 705000.0
# 1300000.00075
# 646950.0
# 750000.0
# 1794136.1545
# 4800000.0
# 708000.0
# 1650000.0
# 940000.0
# 1050000.0
# 2350000.0
# 804999.98715
# 750000.0
# 900000.0
# 820000.045
# 1230000.0
# 890000.0
# 665000.0
# 680000.0
# 1100000.0
# 795000.0
# 744999.9941
# 803000.0
# 710000.0
# 1096410.0
# 650000.0
# 1700000.0
# 795000.0
# 662600.0
# 2000000.0
# 900000.0
# 1065000.0
# 500

# %%
rppr_df2['Post_Code_or_County'].unique()
# Out:
# array(['Dublin', 'Dublin 1', 'Leitrim', 'Galway', 'Kildare', 'Dublin 15',
#        'Kerry', 'Cork', 'Mayo', 'Limerick', 'Roscommon', 'Dublin 18',
#        'Dublin 7', 'Dublin 5', 'Dublin 12', 'Donegal', 'Dublin 17',
#        'Sligo', 'Dublin 22', 'Dublin 11', 'Meath', 'Offaly', 'Kilkenny',
#        'Dublin 13', 'Wicklow', 'Clare', 'Dublin 3', 'Waterford', 'Louth',
#        'Dublin 14', 'Dublin 4', 'Dublin 6', 'Tipperary', 'Wexford',
#        'Laois', 'Cavan', 'Dublin 16', 'Monaghan', 'Dublin 9', 'Westmeath',
#        'Carlow', 'Dublin 24', 'Longford', 'Dublin 8', 'Dublin 10',
#        'Dublin 6w', 'Dublin 2', 'Dublin 20'], dtype=object)

# %%
rppr_df2.dtypes
# Out:
# Year_of_Sale                 int64
# Post_Code_or_County         object
# Month_of_Sale                int64
# Address                     object
# Major_Train_Route           object
# County                      object
# Price                      float64
# Not_Full_Market_Price       object
# Description_of_Property     object
# dtype: object

# %%
rppr_df2['Post_Code_or_County'] = rppr_df2['Post_Code_or_County'].astype('category')
rppr_df2['Address'] = rppr_df2['Address'].astype('category')
rppr_df2['Major_Train_Route'] = rppr_df2['Major_Train_Route'].astype('category')
rppr_df2['County'] = rppr_df2['County'].astype('category')
rppr_df2['Not_Full_Market_Price'] = rppr_df2['Not_Full_Market_Price'].astype('category')
rppr_df2['Description_of_Property'] = rppr_df2['Description_of_Property'].astype('category')

# %%
rppr_df2.dtypes
# Out:
# Year_of_Sale                  int64
# Post_Code_or_County        category
# Month_of_Sale                 int64
# Address                    category
# Major_Train_Route          category
# County                     category
# Price                       float64
# Not_Full_Market_Price      category
# Description_of_Property    category
# dtype: object

# %%
rppr_df2
# Out:
#       Year_of_Sale Post_Code_or_County  Month_of_Sale  \
# 0             2016              Dublin              1
# 1             2013            Dublin 1              3
# 2             2011             Leitrim              1
# 3             2016              Galway             10
# 4             2014             Kildare              8
# ...            ...                 ...            ...
# 9995          2021                Mayo             10
# 9996          2021             Leitrim             12
# 9997          2016           Waterford              8
# 9998          2021            Limerick             11
# 9999          2017            Kilkenny              9
#
#                                                 Address Major_Train_Route  \
# 0     Malahide, Fingal, County Dublin, Leinster, K36...               Yes
# 1     Parnell Street, Rotunda B ED, Dublin, Dublin 1...               Yes
# 2     Ballinamore, Ballinamore Municipal District, C...                No
# 3     Murrough Avenue, Murrough, Cathair na Gaillimh...               Yes
# 4     Newbridge, The Municipal District of Kildare —...                No
# ...                                                 ...               ...
# 9995  Castlebar, Castlebar Municipal District, Count...               Yes
# 9996  Ballinamore, Ballinamore Municipal District, C...                No
# 9997  Finisterre Lawn, Landsend, Abbeyside, Dungarva...               Yes
# 9998  Kilmallock, The Municipal District of Cappamor...               Yes
# 9999          County Kilkenny, Leinster, Éire / Ireland                No
#
#          County       Price Not_Full_Market_Price  \
# 0        Dublin  260000.000                    No
# 1        Dublin   81000.000                    No
# 2       Leitrim  155000.000                    No
# 3        Galway   60000.000                    No
# 4       Kildare  314999.955                    No
# ...         ...         ...                   ...
# 9995       Mayo   72000.000                   Yes
# 9996    Leitrim  112000.000                    No
# 9997  Waterford   60000.000                    No
# 9998   Limerick   80000.000                    No
# 9999   Kilkenny   90800.000                   Yes
#
#                     Description_of_Property
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 3     Second-Hand Dwelling house /Apartment
# 4             New Dwelling house /Apartment
# ...                                     ...
# 9995  Second-Hand Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9997  Second-Hand Dwelling house /Apartment
# 9998  Second-Hand Dwelling house /Apartment
# 9999          New Dwelling house /Apartment
#
# [10000 rows x 9 columns]

# %%
rppr_df2.to_csv('ppr-14332591-clean.csv')
